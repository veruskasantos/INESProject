# %% [markdown]
# # Correlation Script

# %% [markdown]
# Input variables: 57

# %% [raw]
# route,tripNum,shapeId,routeFrequency,shapeSequence,shapeLat,shapeLon,distanceTraveledShape,busCode,gpsPointId,gpsLat,gpsLon,distanceToShapePoint,gps_datetime,stopPointId,problem,alertDateTime,alertSubtype,alertType,alertRoadType,alertConfidence,alertNComments,alertNImages,alertNThumbsUp,alertReliability,alertReportMood,alertReportRating,alertSpeed,alertLatitude,alertLongitude,alertDistanceToClosestShapePoint,alertIsJamUnifiedAlert,alertInScale,jamUpdateDateTime,jamExpirationDateTime,jamBlockType,jamDelay,jamLength,jamLevel,jamSeverity,jamSpeedKM,jamDistanceToClosestShapePoint,headway,busBunching,nextBusCode,DAY(jamUpdateDateTime),DAY(jamExpirationDateTime),YEAR(gps_datetime),YEAR(alertDateTime),YEAR(jamUpdateDateTime),YEAR(jamExpirationDateTime),MONTH(gps_datetime),MONTH(alertDateTime),MONTH(jamUpdateDateTime),MONTH(jamExpirationDateTime),WEEKDAY(gps_datetime),WEEKDAY(alertDateTime),WEEKDAY(jamUpdateDateTime),WEEKDAY(jamExpirationDateTime)

# %%
# Importing required packages

import pandas as pd
import pandas_profiling
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Choose the city of analysis

city = 'Recife'
# city = 'CG'
# city = 'Curitiba'

# %%
# Put the integrated data path

file_name = "new_feats_data.csv"
new_feats_data_path = os.getcwd() + "/../data/output/" + city + "/" + file_name

# %%
# Importing the data after Feature Engineering

df = pd.read_csv(new_feats_data_path, index_col=None, header=0)

df.head()
# Out:
#    route  tripNum    shapeId routeFrequency  shapeSequence  shapeLat  \
# 0     96        1  Route_219  low_frequency          22857 -8.046589
# 1     96        1  Route_219  low_frequency          22857 -8.046589
# 2     96        1  Route_219  low_frequency          22857 -8.046589
# 3     96        2  Route_219  low_frequency          22857 -8.046589
# 4     96        2  Route_219  low_frequency          22857 -8.046589
#
#     shapeLon  distanceTraveledShape  busCode  gpsPointId  ...  \
# 0 -34.878125                 3606.0    50665         NaN  ...
# 1 -34.878125                 3606.0    50673         NaN  ...
# 2 -34.878125                 3606.0    50662         NaN  ...
# 3 -34.878125                 3606.0    50673         NaN  ...
# 4 -34.878125                 3606.0    50662    176265.0  ...
#
#    YEAR(jamUpdateDateTime)  YEAR(jamExpirationDateTime)  MONTH(gps_datetime)  \
# 0                   2018.0                          NaN                   12
# 1                   2018.0                          NaN                   12
# 2                   2018.0                          NaN                   12
# 3                   2018.0                          NaN                   12
# 4                   2018.0                          NaN                   12
#
#    MONTH(alertDateTime) MONTH(jamUpdateDateTime) MONTH(jamExpirationDateTime)  \
# 0                  12.0                     12.0                          NaN
# 1                  12.0                     12.0                          NaN
# 2                  12.0                     12.0                          NaN
# 3                  12.0                     12.0                          NaN
# 4                  12.0                     12.0                          NaN
#
#   WEEKDAY(gps_datetime)  WEEKDAY(alertDateTime)  WEEKDAY(jamUpdateDateTime)  \
# 0                     5                     5.0                         5.0
# 1                     5                     5.0                         5.0
# 2                     5                     5.0                         5.0
# 3                     5                     5.0                         5.0
# 4                     5                     5.0                         5.0
#
#    WEEKDAY(jamExpirationDateTime)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 57 columns]

# %%
df.dtypes
# Out:
# route                                 int64
# tripNum                               int64
# shapeId                              object
# routeFrequency                       object
# shapeSequence                         int64
# shapeLat                            float64
# shapeLon                            float64
# distanceTraveledShape               float64
# busCode                               int64
# gpsPointId                          float64
# gpsLat                              float64
# gpsLon                              float64
# distanceToShapePoint                float64
# stopPointId                           int64
# problem                              object
# alertSubtype                         object
# alertType                            object
# alertRoadType                       float64
# alertConfidence                     float64
# alertNComments                      float64
# alertNImages                        float64
# alertNThumbsUp                      float64
# alertReliability                    float64
# alertReportMood                     float64
# alertReportRating                   float64
# alertSpeed                          float64
# alertLatitude                       float64
# alertLongitude                      float64
# alertDistanceToClosestShapePoint    float64
# alertIsJamUnifiedAlert                 bool
# alertInScale                           bool
# jamBlockType                         object
# jamDelay                            float64
# jamLength                           float64
# jamLevel                            float64
# jamSeverity                         float64
# jamSpeedKM                          float64
# jamDistanceToClosestShapePoint      float64
# headway                               int64
# busBunching                            bool
# nextBusCode                           int64
# DAY(gps_datetime)                     int64
# DAY(alertDateTime)                  float64
# DAY(jamUpdateDateTime)              float64
# DAY(jamExpirationDateTime)          float64
# YEAR(gps_datetime)                    int64
# YEAR(alertDateTime)                 float64
# YEAR(jamUpdateDateTime)             float64
# YEAR(jamExpirationDateTime)         float64
# MONTH(gps_datetime)                   int64
# MONTH(alertDateTime)                float64
# MONTH(jamUpdateDateTime)            float64
# MONTH(jamExpirationDateTime)        float64
# WEEKDAY(gps_datetime)                 int64
# WEEKDAY(alertDateTime)              float64
# WEEKDAY(jamUpdateDateTime)          float64
# WEEKDAY(jamExpirationDateTime)      float64
# dtype: object

# %%
# Descriptive statistics
pandas_profiling.ProfileReport(df, check_correlation=True, correlation_threshold=0.5)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>57 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>1123095 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>17.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>465.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>435.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>22 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_DAY(alertDateTime)"><code>DAY(alertDateTime)</code></a> is highly correlated with <a href="#pp_var_DAY(gps_datetime)"><code>DAY(gps_datetime)</code></a> (ρ = 0.89733) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_DAY(jamExpirationDateTime)"><code>DAY(jamExpirationDateTime)</code></a> is highly correlated with <a href="#pp_var_jamLength"><code>jamLength</code></a> (ρ = 0.52102) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_DAY(jamUpdateDateTime)"><code>DAY(jamUpdateDateTime)</code></a> is highly correlated with <a href="#pp_var_DAY(alertDateTime)"><code>DAY(alertDateTime)</code></a> (ρ = 0.89053) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_MONTH(alertDateTime)"><code>MONTH(alertDateTime)</code></a> has 657008 / 58.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_MONTH(gps_datetime)"><code>MONTH(gps_datetime)</code></a> has constant value 12 <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_MONTH(jamExpirationDateTime)"><code>MONTH(jamExpirationDateTime)</code></a> is highly correlated with <a href="#pp_var_DAY(jamUpdateDateTime)"><c

# %% [markdown]
# ## 1. Checking Correlation

# %%
def plot_corr(df_corr):
    fig, ax = plt.subplots(figsize=(14,14))
    
    # Drop self-correlations
    dropSelf = np.zeros_like(df_corr)
    dropSelf[np.triu_indices_from(dropSelf)] = True
    colormap = sns.diverging_palette(220, 10, as_cmap=True)
    
    # Generate Color Map
    sns.heatmap(df_corr, xticklabels=df_corr.columns.values, yticklabels=df_corr.columns.values, 
                cmap=colormap, mask=dropSelf, linewidths=.4 )

# %%
def showCorrelatedPositiveVar(df_corr, min_corr_positive_value):
    indices = np.where(df_corr >= min_corr_positive_value)
    indices = [(df_corr.index[x], df_corr.columns[y]) for x, y in zip(*indices)
                                        if x != y]
    return indices


def showCorrelatedNegativeVar(df_corr, min_corr_negative_value):
    indices = np.where(df_corr <= min_corr_negative_value)
    indices = [(df_corr.index[x], df_corr.columns[y]) for x, y in zip(*indices)
                                        if x != y]
    return indices

# %% [markdown]
# ### 1.1. Pearson
#
# The Pearson correlation coefficient is a widely used approach that measures the **linear dependence** between two variables. The correlation coefficient ranges from -1 to 1.
# * 1: total positive correlation
# * -1: total negative correlation
# * 0: no correlation or non-linear correlation

# %%
pearson_corr = df.corr()
pearson_corr
# Out:
#                                      route   tripNum  shapeSequence  shapeLat  \
# route                             1.000000  0.102165       0.826754  0.248498
# tripNum                           0.102165  1.000000       0.091997  0.138114
# shapeSequence                     0.826754  0.091997       1.000000  0.323160
# shapeLat                          0.248498  0.138114       0.323160  1.000000
# shapeLon                          0.325267 -0.055591       0.249095  0.261171
# distanceTraveledShape            -0.069354 -0.139275      -0.006152 -0.037277
# busCode                           0.409819  0.068194       0.358020  0.529017
# gpsPointId                        0.359503  0.165133       0.332301  0.471820
# gpsLat                            0.255579  0.159055       0.335781  0.999971
# gpsLon                            0.304023 -0.027717       0.251975  0.251505
# distanceToShapePoint             -0.007066 -0.013251       0.003017  0.002411
# stopPointId                       0.047504 -0.018902      -0.012328  0.078107
# alertRoadType                    -0.018226 -0.006618      -0.019742  0.115797
# alertConfidence                  -0.027392  0.006359      -0.019703 -0.015908
# alertNComments                   -0.024036  0.002536      -0.019810  0.004241
# alertNImages                      0.028545 -0.001496       0.022489 -0.011451
# alertNThumbsUp                   -0.015191  0.007498      -0.006215 -0.012711
# alertReliability                 -0.039965  0.016301      -0.030023  0.007258
# alertReportMood                   0.002667  0.018799      -0.002638  0.046519
# alertReportRating                -0.021631  0.001699      -0.011376 -0.044179
# alertSpeed                             NaN       NaN            NaN       NaN
# alertLatitude                    -0.361512  0.003045      -0.313992  0.997379
# alertLongitude                   -0.057875  0.012956       0.011661 -0.315968
# alertDistanceToClosestShapePoint  0.058152  0.000337       0.060895  0.209452
# alertIsJamUnifiedAlert            0.159396  0.120585       0.229204  0.587544
# alertInScale                      0.144413  0.113015       0.209048  0.573075
# jamDelay                         -0.005890  0.008080      -0.009127 -0.061035
# jamLength                         0.030096 -0.000359       0.017774 -0.107954
# jamLevel                         -0.046734  0.001290      -0.043170  0.005542
# jamSeverity                      -0.005731  0.024220      -0.011453 -0.078171
# jamSpeedKM                        0.083157 -0.053366       0.064360 -0.126939
# jamDistanceToClosestShapePoint    0.049978 -0.036448       0.055778  0.162580
# headway                           0.115857 -0.063825       0.125161  0.099996
# busBunching                      -0.099888 -0.017779      -0.105381 -0.071127
# nextBusCode                       0.409837  0.068274       0.358007  0.528972
# DAY(gps_datetime)                 0.016797 -0.022791       0.011362 -0.004368
# DAY(alertDateTime)                0.023592 -0.060347       0.012293 -0.055475
# DAY(jamUpdateDateTime)            0.017366 -0.042474       0.004520 -0.055184
# DAY(jamExpirationDateTime)        0.441448 -0.184215       0.415750 -0.611648
# YEAR(gps_datetime)                     NaN       NaN            NaN       NaN
# YEAR(alertDateTime)                    NaN       NaN            NaN       NaN
# YEAR(jamUpdateDateTime)                NaN       NaN            NaN       NaN
# YEAR(jamExpirationDateTime)       0.140416 -0.246491       0.205949 -0.340514
# MONTH(gps_datetime)                    NaN       NaN            NaN       NaN
# MONTH(alertDateTime)             -0.011711  0.003970      -0.010115  0.009905
# MONTH(jamUpdateDateTime)               NaN       NaN            NaN       NaN
# MONTH(jamExpirationDateTime)     -0.130611  0.240571      -0.197747  0.334614
# WEEKDAY(gps_datetime)            -0.030098  0.023875      -0.008545 -0.017004
# WEEKDAY(alertDateTime)           -0.000584  0.084695       0.019538  0.023804
# WEEKDAY(jamUpdateDateTime)       -0.007735  0.078369       0.011837  0.058372
# WEEKDAY(jamExpirationDateTime)    0.238949  0.381650       0.160743 -0.179130
#
#                                   shapeLon  distanceTraveledShape   busCode  \
# route                             0.325267              -0.069354  0.409819
# tripNum                          -0.055591              -0.139275  0.068194
# shapeSequence                     0.249095              -0.006152  0.358020
# shapeLat                          0.261171              -0.037277  0.529017
# shapeLon                          1.000000               0.123186  0.742745
# distanceTraveledShape             0.123186               1.000000  0.019722
# busCode                           0.742745               0.019722  1.000000
# gpsPointId                        0.541633              -0.034433  0.798171
# gpsLat                            0.251555              -0.064009  0.554205
# gpsLon                            0.999960               0.095425  0.697540
# distanceToShapePoint              0.004129               0.001974 -0.034669
# stopPointId                       0.444819               0.052055  0.337482
# alertRoadType                    -0.284135              -0.020039 -0.164984
# alertConfidence                   0.060286               0.011623  0.046206
# alertNComments                   -0.047156               0.000224 -0.007331
# alertNImages                     -0.012635               0.010625 -0.011535
# alertNThumbsUp                    0.076472               0.016144  0.068764
# alertReliability                  0.045698               0.011097  0.051862
# alertReportMood                  -0.060848              -0.058737 -0.025372
# alertReportRating                 0.073507               0.032457  0.025882
# alertSpeed                             NaN                    NaN       NaN
# alertLatitude                    -0.318996              -0.186210  0.124135
# alertLongitude                    0.998257               0.109318  0.641028
# alertDistanceToClosestShapePoint -0.151342              -0.024915 -0.030677
# alertIsJamUnifiedAlert            0.036804               0.005227  0.254557
# alertInScale                     -0.003054              -0.000452  0.207038
# jamDelay                          0.019943               0.011574  0.001303
# jamLength                        -0.003593               0.007273 -0.054218
# jamLevel                          0.005628               0.006907  0.029768
# jamSeverity                       0.035917               0.019159  0.006050
# jamSpeedKM                       -0.007884               0.015803 -0.058876
# jamDistanceToClosestShapePoint   -0.127105               0.016607 -0.004567
# headway                           0.047452              -0.010293  0.097170
# busBunching                      -0.062465               0.015474 -0.101039
# nextBusCode                       0.742742               0.019681  0.999829
# DAY(gps_datetime)                -0.001509               0.001099 -0.005486
# DAY(alertDateTime)               -0.005100               0.002710 -0.026729
# DAY(jamUpdateDateTime)           -0.012577              -0.001051 -0.034563
# DAY(jamExpirationDateTime)       -0.868475               0.656460 -0.834949
# YEAR(gps_datetime)                     NaN                    NaN       NaN
# YEAR(alertDateTime)                    NaN                    NaN       NaN
# YEAR(jamUpdateDateTime)                NaN                    NaN       NaN
# YEAR(jamExpirationDateTime)      -0.674576               0.654309 -0.682259
# MONTH(gps_datetime)                    NaN                    NaN       NaN
# MONTH(alertDateTime)             -0.027704              -0.019176 -0.041436
# MONTH(jamUpdateDateTime)               NaN                    NaN       NaN
# MONTH(jamExpirationDateTime)      0.676796              -0.667773  0.681705
# WEEKDAY(gps_datetime)            -0.052387               0.000969 -0.029399
# WEEKDAY(alertDateTime)            0.025586              -0.000361  0.043664
# WEEKDAY(jamUpdateDateTime)       -0.003492              -0.004428  0.030037
# WEEKDAY(jamExpirationDateTime)   -0.349986               0.143212 -0.252510
#
#                                   gpsPointId    gpsLat    gpsLon  ...  \
# route                               0.359503  0.255579  0.304023  ...
# tripNum                             0.165133  0.159055 -0.027717  ...
# shapeSequence                       0.332301  0.335781  0.251975  ...
# shapeLat                            0.471820  0.999971  0.251505  ...
# shapeLon                            0.541633  0.251555  0.999960  ...
# distanceTraveledShape              -0.034433 -0.064009  0.095425  ...
# busCode                             0.798171  0.554205  0.697540  ...
# gpsPointId                          1.000000  0.471870  0.541534  ...
# gpsLat                              0.471870  1.000000  0.251478  ...
# gpsLon                              0.541534  0.251478  1.000000  ...
# distanceToShapePoint               -0.025442  0.001687  0.000994  ...
# stopPointId                         0.215496  0.090727  0.384580  ...
# alertRoadType                      -0.129348  0.123436 -0.277685  ...
# alertConfidence                     0.011415 -0.011405  0.060460  ...
# alertNComments                     -0.016755  0.002538 -0.033717  ...
# alertNImages                        0.003267 -0.002644 -0.001021  ...
# alertNThumbsUp                      0.026500 -0.009285  0.076193  ...
# alertReliability                   -0.006791  0.017343  0.043038  ...
# alertReportMood                    -0.028734  0.052273 -0.065803  ...
# alertReportRating                   0.016217 -0.038395  0.067110  ...
# alertSpeed                               NaN       NaN       NaN  ...
# alertLatitude                       0.070653  0.997680 -0.319339  ...
# alertLongitude                      0.453745 -0.316458  0.998304  ...
# alertDistanceToClosestShapePoint   -0.038265  0.210959 -0.171209  ...
# alertIsJamUnifiedAlert              0.320711  0.589743  0.032985  ...
# alertInScale                        0.283892  0.576543 -0.006172  ...
# jamDelay                            0.108896 -0.057014  0.021096  ...
# jamLength                           0.075689 -0.104173 -0.015211  ...
# jamLevel                            0.116810  0.020368  0.013924  ...
# jamSeverity                         0.161971 -0.068381  0.030537  ...
# jamSpeedKM                         -0.006441 -0.126939 -0.021251  ...
# jamDistanceToClosestShapePoint     -0.046694  0.150528 -0.138109  ...
# headway                             0.029046  0.109561 -0.001471  ...
# busBunching                        -0.050411 -0.071359 -0.047707  ...
# nextBusCode                         0.797278  0.554190  0.697550  ...
# DAY(gps_datetime)                   0.172910 -0.013236  0.004153  ...
# DAY(alertDateTime)                  0.095444 -0.051506 -0.010385  ...
# DAY(jamUpdateDateTime)              0.181366 -0.055031 -0.013603  ...
# DAY(jamExpirationDateTime)         -0.436789 -0.605794 -0.837354  ...
# YEAR(gps_datetime)                       NaN       NaN       NaN  ...
# YEAR(alertDateTime)                      NaN       NaN       NaN  ...
# YEAR(jamUpdateDateTime)                  NaN       NaN       NaN  ...
# YEAR(jamExpirationDateTime)        -0.522831 -0.272987 -0.603124  ...
# MONTH(gps_datetime)                      NaN       NaN       NaN  ...
# MONTH(alertDateTime)               -0.025431  0.011247 -0.027524  ...
# MONTH(jamUpdateDateTime)                 NaN       NaN       NaN  ...
# MONTH(jamExpirationDateTime)        0.520844  0.269219  0.604916  ...
# WEEKDAY(gps_datetime)              -0.336476  0.002019 -0.048120  ...
# WEEKDAY(alertDateTime)             -0.291933  0.033825  0.012739  ...
# WEEKDAY(jamUpdateDateTime)         -0.326379  0.064292 -0.008178  ...
# WEEKDAY(jamExpirationDateTime)     -0.138623 -0.116189 -0.317844  ...
#
#                                   YEAR(jamUpdateDateTime)  \
# route                                                 NaN
# tripNum                                               NaN
# shapeSequence                                         NaN
# shapeLat                                              NaN
# shapeLon                                              NaN
# distanceTraveledShape                                 NaN
# busCode                                               NaN
# gpsPointId                                            NaN
# gpsLat                                                NaN
# gpsLon                                                NaN
# distanceToShapePoint                                  NaN
# stopPointId                                           NaN
# alertRoadType                                         NaN
# alertConfidence                                       NaN
# alertNComments                                        NaN
# alertNImages                                          NaN
# alertNThumbsUp                                        NaN
# alertReliability                                      NaN
# alertReportMood                                       NaN
# alertReportRating                                     NaN
# alertSpeed                                            NaN
# alertLatitude                                         NaN
# alertLongitude                                        NaN
# alertDistanceToClosestShapePoint                      NaN
# alertIsJamUnifiedAlert                                NaN
# alertInScale                                          NaN
# jamDelay                                              NaN
# jamLength                                             NaN
# jamLevel                                              NaN
# jamSeverity                                           NaN
# jamSpeedKM                                            NaN
# jamDistanceToClosestShapePoint                        NaN
# headway                                               NaN
# busBunching                                           NaN
# nextBusCode                                           NaN
# DAY(gps_datetime)                                     NaN
# DAY(alertDateTime)                                    NaN
# DAY(jamUpdateDateTime)                                NaN
# DAY(jamExpirationDateTime)                            NaN
# YEAR(gps_datetime)                                    NaN
# YEAR(alertDateTime)                                   NaN
# YEAR(jamUpdateDateTime)                               NaN
# YEAR(jamExpirationDateTime)                           NaN
# MONTH(gps_datetime)                                   NaN
# MONTH(alertDateTime)                                  NaN
# MONTH(jamUpdateDateTime)                              NaN
# MONTH(jamExpirationDateTime)                          NaN
# WEEKDAY(gps_datetime)                                 NaN
# WEEKDAY(alertDateTime)                                NaN
# WEEKDAY(jamUpdateDateTime)                            NaN
# WEEKDAY(jamExpirationDateTime)                        NaN
#
#                                   YEAR(jamExpirationDateTime)  \
# route                                                0.140416
# tripNum                                             -0.246491
# shapeSequence                                        0.205949
# shapeLat                                            -0.340514
# shapeLon                                            -0.674576
# distanceTraveledShape                                0.654309
# busCode                                             -0.682259
# gpsPointId                                          -0.522831
# gpsLat                                              -0.272987
# gpsLon                                              -0.603124
# distanceToShapePoint                                 0.034512
# stopPointId                                          0.129401
# alertRoadType                                        0.475237
# alertConfidence                                      0.216723
# alertNComments                                       0.184863
# alertNImages                                              NaN
# alertNThumbsUp                                       0.181533
# alertReliability                                     0.264353
# alertReportMood                                      0.198054
# alertReportRating                                   -0.236839
# alertSpeed                                                NaN
# alertLatitude                                       -0.178831
# alertLongitude                                      -0.752552
# alertDistanceToClosestShapePoint                     0.205204
# alertIsJamUnifiedAlert                              -0.578153
# alertInScale                                        -0.407395
# jamDelay                                                  NaN
# jamLength                                            0.387632
# jamLevel                                                  NaN
# jamSeverity                                          0.046215
# jamSpeedKM                                                NaN
# jamDistanceToClosestShapePoint                       0.048294
# headway                                              0.307418
# busBunching                                         -0.055363
# nextBusCode                                         -0.682626
# DAY(gps_datetime)                                   -0.684390
# DAY(alertDateTime)                                  -0.604851
# DAY(jamUpdateDateTime)                              -0.684390
# DAY(jamExpirationDateTime)                           0.895761
# YEAR(gps_datetime)                                        NaN
# YEAR(alertDateTime)                                       NaN
# YEAR(jamUpdateDateTime)                                   NaN
# YEAR(jamExpirationDateTime)                          1.000000
# MONTH(gps_datetime)                                       NaN
# MONTH(alertDateTime)                                      NaN
# MONTH(jamUpdateDateTime)                                  NaN
# MONTH(jamExpirationDateTime)                        -0.999090
# WEEKDAY(gps_datetime)                                0.374372
# WEEKDAY(alertDateTime)                               0.380641
# WEEKDAY(jamUpdateDateTime)                           0.374372
# WEEKDAY(jamExpirationDateTime)                       0.236663
#
#                                   MONTH(gps_datetime)  MONTH(alertDateTime)  \
# route                                             NaN             -0.011711
# tripNum                                           NaN              0.003970
# shapeSequence                                     NaN             -0.010115
# shapeLat                                          NaN              0.009905
# shapeLon                                          NaN             -0.027704
# distanceTraveledShape                             NaN             -0.019176
# busCode                                           NaN             -0.041436
# gpsPointId                                        NaN             -0.025431
# gpsLat                                            NaN              0.011247
# gpsLon                                            NaN             -0.027524
# distanceToShapePoint                              NaN             -0.001359
# stopPointId                                       NaN             -0.005670
# alertRoadType                                     NaN              0.012294
# alertConfidence                                   NaN             -0.145774
# alertNComments                                    NaN             -0.080636
# alertNImages                                      NaN              0.002810
# alertNThumbsUp                                    NaN             -0.495350
# alertReliability                                  NaN             -0.086688
# alertReportMood                                   NaN              0.039132
# alertReportRating                                 NaN              0.012325
# alertSpeed                                        NaN                   NaN
# alertLatitude                                     NaN              0.010089
# alertLongitude                                    NaN             -0.027594
# alertDistanceToClosestShapePoint                  NaN              0.002615
# alertIsJamUnifiedAlert                            NaN                   NaN
# alertInScale                                      NaN              0.014232
# jamDelay                                          NaN             -0.004503
# jamLength                                         NaN             -0.027150
# jamLevel                                          NaN              0.014712
# jamSeverity                                       NaN             -0.004681
# jamSpeedKM                                        NaN             -0.022033
# jamDistanceToClosestShapePoint                    NaN             -0.007503
# headway                                           NaN             -0.011774
# busBunching                                       NaN              0.004894
# nextBusCode                                       NaN             -0.041430
# DAY(gps_datetime)                                 NaN              0.063881
# DAY(alertDateTime)                                NaN             -0.369507
# DAY(jamUpdateDateTime)                            NaN              0.065178
# DAY(jamExpirationDateTime)                        NaN                   NaN
# YEAR(gps_datetime)                                NaN                   NaN
# YEAR(alertDateTime)                               NaN                   NaN
# YEAR(jamUpdateDateTime)                           NaN                   NaN
# YEAR(jamExpirationDateTime)                       NaN                   NaN
# MONTH(gps_datetime)                               NaN                   NaN
# MONTH(alertDateTime)                              NaN              1.000000
# MONTH(jamUpdateDateTime)                          NaN                   NaN
# MONTH(jamExpirationDateTime)                      NaN                   NaN
# WEEKDAY(gps_datetime)                             NaN             -0.011406
# WEEKDAY(alertDateTime)                            NaN              0.003203
# WEEKDAY(jamUpdateDateTime)                        NaN             -0.009229
# WEEKDAY(jamExpirationDateTime)                    NaN                   NaN
#
#                                   MONTH(jamUpdateDateTime)  \
# route                                                  NaN
# tripNum                                                NaN
# shapeSequence                                          NaN
# shapeLat                                               NaN
# shapeLon                                               NaN
# distanceTraveledShape                                  NaN
# busCode                                                NaN
# gpsPointId                                             NaN
# gpsLat                                                 NaN
# gpsLon                                                 NaN
# distanceToShapePoint                                   NaN
# stopPointId                                            NaN
# alertRoadType                                          NaN
# alertConfidence                                        NaN
# alertNComments                                         NaN
# alertNImages                                           NaN
# alertNThumbsUp                                         NaN
# alertReliability                                       NaN
# alertReportMood                                        NaN
# alertReportRating                                      NaN
# alertSpeed                                             NaN
# alertLatitude                                          NaN
# alertLongitude                                         NaN
# alertDistanceToClosestShapePoint                       NaN
# alertIsJamUnifiedAlert                                 NaN
# alertInScale                                           NaN
# jamDelay                                               NaN
# jamLength                                              NaN
# jamLevel                                               NaN
# jamSeverity                                            NaN
# jamSpeedKM                                             NaN
# jamDistanceToClosestShapePoint                         NaN
# headway                                                NaN
# busBunching                                            NaN
# nextBusCode                                            NaN
# DAY(gps_datetime)                                      NaN
# DAY(alertDateTime)                                     NaN
# DAY(jamUpdateDateTime)                                 NaN
# DAY(jamExpirationDateTime)                             NaN
# YEAR(gps_datetime)                                     NaN
# YEAR(alertDateTime)                                    NaN
# YEAR(jamUpdateDateTime)                                NaN
# YEAR(jamExpirationDateTime)                            NaN
# MONTH(gps_datetime)                                    NaN
# MONTH(alertDateTime)                                   NaN
# MONTH(jamUpdateDateTime)                               NaN
# MONTH(jamExpirationDateTime)                           NaN
# WEEKDAY(gps_datetime)                                  NaN
# WEEKDAY(alertDateTime)                                 NaN
# WEEKDAY(jamUpdateDateTime)                             NaN
# WEEKDAY(jamExpirationDateTime)                         NaN
#
#                                   MONTH(jamExpirationDateTime)  \
# route                                                -0.130611
# tripNum                                               0.240571
# shapeSequence                                        -0.197747
# shapeLat                                              0.334614
# shapeLon                                              0.676796
# distanceTraveledShape                                -0.667773
# busCode                                               0.681705
# gpsPointId                                            0.520844
# gpsLat                                                0.269219
# gpsLon                                                0.604916
# distanceToShapePoint                                 -0.032734
# stopPointId                                          -0.150051
# alertRoadType                                        -0.497624
# alertConfidence                                      -0.229285
# alertNComments                                       -0.156062
# alertNImages                                               NaN
# alertNThumbsUp                                       -0.198690
# alertReliability                                     -0.279523
# alertReportMood                                      -0.181994
# alertReportRating                                     0.225812
# alertSpeed                                                 NaN
# alertLatitude                                         0.161124
# alertLongitude                                        0.758210
# alertDistanceToClosestShapePoint                     -0.222731
# alertIsJamUnifiedAlert                                0.575001
# alertInScale                                          0.399149
# jamDelay                                                   NaN
# jamLength                                            -0.397393
# jamLevel                                                   NaN
# jamSeverity                                          -0.050619
# jamSpeedKM                                                 NaN
# jamDistanceToClosestShapePoint                       -0.034221
# headway                                              -0.277368
# busBunching                                           0.053262
# nextBusCode                                           0.682080
# DAY(gps_datetime)                                     0.675030
# DAY(alertDateTime)                                    0.599652
# DAY(jamUpdateDateTime)                                0.675030
# DAY(jamExpirationDateTime)                           -0.897902
# YEAR(gps_datetime)                                         NaN
# YEAR(alertDateTime)                                        NaN
# YEAR(jamUpdateDateTime)                                    NaN
# YEAR(jamExpirationDateTime)                          -0.999090
# MONTH(gps_datetime)                                        NaN
# MONTH(alertDateTime)                                       NaN
# MONTH(jamUpdateDateTime)                                   NaN
# MONTH(jamExpirationDateTime)                          1.000000
# WEEKDAY(gps_datetime)                                -0.370500
# WEEKDAY(alertDateTime)                               -0.383290
# WEEKDAY(jamUpdateDateTime)                           -0.370500
# WEEKDAY(jamExpirationDateTime)                       -0.236448
#
#                                   WEEKDAY(gps_datetime)  \
# route                                         -0.030098
# tripNum                                        0.023875
# shapeSequence                                 -0.008545
# shapeLat                                      -0.017004
# shapeLon                                      -0.052387
# distanceTraveledShape                          0.000969
# busCode                                       -0.029399
# gpsPointId                                    -0.336476
# gpsLat                                         0.002019
# gpsLon                                        -0.048120
# distanceToShapePoint                           0.000220
# stopPointId                                   -0.052592
# alertRoadType                                  0.016504
# alertConfidence                               -0.000012
# alertNComments                                 0.011888
# alertNImages                                   0.002965
# alertNThumbsUp                                 0.010200
# alertReliability                               0.067700
# alertReportMood                                0.037998
# alertReportRating                             -0.026327
# alertSpeed                                          NaN
# alertLatitude                                  0.028439
# alertLongitude                                 0.018284
# alertDistanceToClosestShapePoint               0.071879
# alertIsJamUnifiedAlert                        -0.145647
# alertInScale                                  -0.133182
# jamDelay                                      -0.201701
# jamLength                                     -0.265560
# jamLevel                                      -0.144017
# jamSeverity                                   -0.301657
# jamSpeedKM                                    -0.114400
# jamDistanceToClosestShapePoint                 0.097847
# headway                                        0.095751
# busBunching                                   -0.087277
# nextBusCode                                   -0.029413
# DAY(gps_datetime)                             -0.480979
# DAY(alertDateTime)                            -0.342038
# DAY(jamUpdateDateTime)                        -0.483041
# DAY(jamExpirationDateTime)                     0.232498
# YEAR(gps_datetime)                                  NaN
# YEAR(alertDateTime)                                 NaN
# YEAR(jamUpdateDateTime)                             NaN
# YEAR(jamExpirationDateTime)                    0.374372
# MONTH(gps_datetime)                                 NaN
# MONTH(alertDateTime)                          -0.011406
# MONTH(jamUpdateDateTime)                            NaN
# MONTH(jamExpirationDateTime)                  -0.370500
# WEEKDAY(gps_datetime)                          1.000000
# WEEKDAY(alertDateTime)                         0.970447
# WEEKDAY(jamUpdateDateTime)                     0.999894
# WEEKDAY(jamExpirationDateTime)                 0.387810
#
#                                   WEEKDAY(alertDateTime)  \
# route                                          -0.000584
# tripNum                                         0.084695
# shapeSequence                                   0.019538
# shapeLat                                        0.023804
# shapeLon                                        0.025586
# distanceTraveledShape                          -0.000361
# busCode                                         0.043664
# gpsPointId                                     -0.291933
# gpsLat                                          0.033825
# gpsLon                                          0.012739
# distanceToShapePoint                            0.003664
# stopPointId                                    -0.048908
# alertRoadType                                   0.010223
# alertConfidence                                -0.014442
# alertNComments                                  0.010066
# alertNImages                                    0.002805
# alertNThumbsUp                                 -0.001280
# alertReliability                                0.049866
# alertReportMood                                 0.040257
# alertReportRating                              -0.031574
# alertSpeed                                           NaN
# alertLatitude                                   0.025117
# alertLongitude                                  0.026946
# alertDistanceToClosestShapePoint                0.075042
# alertIsJamUnifiedAlert                               NaN
# alertInScale                                    0.018534
# jamDelay                                       -0.214176
# jamLength                                      -0.270132
# jamLevel                                       -0.160167
# jamSeverity                                    -0.326757
# jamSpeedKM                                     -0.098598
# jamDistanceToClosestShapePoint                  0.085219
# headway                                         0.085269
# busBunching                                    -0.103408
# nextBusCode                                     0.043672
# DAY(gps_datetime)                              -0.357905
# DAY(alertDateTime)                             -0.332659
# DAY(jamUpdateDateTime)                         -0.349599
# DAY(jamExpirationDateTime)                      0.245210
# YEAR(gps_datetime)                                   NaN
# YEAR(alertDateTime)                                  NaN
# YEAR(jamUpdateDateTime)                              NaN
# YEAR(jamExpirationDateTime)                     0.380641
# MONTH(gps_datetime)                                  NaN
# MONTH(alertDateTime)                            0.003203
# MONTH(jamUpdateDateTime)                             NaN
# MONTH(jamExpirationDateTime)                   -0.383290
# WEEKDAY(gps_datetime)                           0.970447
# WEEKDAY(alertDateTime)                          1.000000
# WEEKDAY(jamUpdateDateTime)                      0.972505
# WEEKDAY(jamExpirationDateTime)                  0.674146
#
#                                   WEEKDAY(jamUpdateDateTime)  \
# route                                              -0.007735
# tripNum                                             0.078369
# shapeSequence                                       0.011837
# shapeLat                                            0.058372
# shapeLon                                           -0.003492
# distanceTraveledShape                              -0.004428
# busCode                                             0.030037
# gpsPointId                                         -0.326379
# gpsLat                                              0.064292
# gpsLon                                             -0.008178
# distanceToShapePoint                                0.005669
# stopPointId                                        -0.048191
# alertRoadType                                       0.037393
# alertConfidence                                    -0.007151
# alertNComments                                      0.016083
# alertNImages                                        0.004311
# alertNThumbsUp                                      0.005390
# alertReliability                                    0.073445
# alertReportMood                                     0.045927
# alertReportRating                                  -0.030746
# alertSpeed                                               NaN
# alertLatitude                                       0.052764
# alertLongitude                                     -0.006158
# alertDistanceToClosestShapePoint                    0.105064
# alertIsJamUnifiedAlert                             -0.347706
# alertInScale                                       -0.283921
# jamDelay                                           -0.201722
# jamLength                                          -0.265601
# jamLevel                                           -0.144002
# jamSeverity                                        -0.301694
# jamSpeedKM                                         -0.114436
# jamDistanceToClosestShapePoint                      0.097839
# headway                                             0.104289
# busBunching                                        -0.101626
# nextBusCode                                         0.030041
# DAY(gps_datetime)                                  -0.482980
# DAY(alertDateTime)                                 -0.332201
# DAY(jamUpdateDateTime)                             -0.482997
# DAY(jamExpirationDateTime)                          0.232498
# YEAR(gps_datetime)                                       NaN
# YEAR(alertDateTime)                                      NaN
# YEAR(jamUpdateDateTime)                                  NaN
# YEAR(jamExpirationDateTime)                         0.374372
# MONTH(gps_datetime)                                      NaN
# MONTH(alertDateTime)                               -0.009229
# MONTH(jamUpdateDateTime)                                 NaN
# MONTH(jamExpirationDateTime)                       -0.370500
# WEEKDAY(gps_datetime)                               0.999894
# WEEKDAY(alertDateTime)                              0.972505
# WEEKDAY(jamUpdateDateTime)                          1.000000
# WEEKDAY(jamExpirationDateTime)                      0.387810
#
#                                   WEEKDAY(jamExpirationDateTime)
# route                                                   0.238949
# tripNum                                                 0.381650
# shapeSequence                                           0.160743
# shapeLat                                               -0.179130
# shapeLon                                               -0.349986
# distanceTraveledShape                                   0.143212
# busCode                                                -0.252510
# gpsPointId                                             -0.138623
# gpsLat                                                 -0.116189
# gpsLon                                                 -0.317844
# distanceToShapePoint                                    0.348639
# stopPointId                                            -0.263922
# alertRoadType                                           0.193884
# alertConfidence                                        -0.003211
# alertNComments                                          0.134026
# alertNImages                                                 NaN
# alertNThumbsUp                                         -0.034747
# alertReliability                                       -0.060996
# alertReportMood                                         0.135751
# alertReportRating                                      -0.367948
# alertSpeed                                                   NaN
# alertLatitude                                           0.106286
# alertLongitude                                         -0.556387
# alertDistanceToClosestShapePoint                        0.294748
# alertIsJamUnifiedAlert                                 -0.094220
# alertInScale                                           -0.051685
# jamDelay                                                     NaN
# jamLength                                               0.168213
# jamLevel                                                     NaN
# jamSeverity                                             0.218747
# jamSpeedKM                                                   NaN
# jamDistanceToClosestShapePoint                         -0.054083
# headway                                                 0.119444
# busBunching                                            -0.095768
# nextBusCode                                            -0.252442
# DAY(gps_datetime)                                      -0.244057
# DAY(alertDateTime)                                     -0.475232
# DAY(jamUpdateDateTime)                                 -0.244057
# DAY(jamExpirationDateTime)                              0.430655
# YEAR(gps_datetime)                                           NaN
# YEAR(alertDateTime)                                          NaN
# YEAR(jamUpdateDateTime)                                      NaN
# YEAR(jamExpirationDateTime)                             0.236663
# MONTH(gps_datetime)                                          NaN
# MONTH(alertDateTime)                                         NaN
# MONTH(jamUpdateDateTime)                                     NaN
# MONTH(jamExpirationDateTime)                           -0.236448
# WEEKDAY(gps_datetime)                                   0.387810
# WEEKDAY(alertDateTime)                                  0.674146
# WEEKDAY(jamUpdateDateTime)                              0.387810
# WEEKDAY(jamExpirationDateTime)                          1.000000
#
# [51 rows x 51 columns]

# %%
plot_corr(pearson_corr)

# %%
showCorrelatedVar(pearson_corr, 0.9, -0.9)
# Out:
# [('route', 'shapeSequence'),
#  ('route', 'shapeLon'),
#  ('route', 'busCode'),
#  ('route', 'gpsPointId'),
#  ('route', 'gpsLon'),
#  ('route', 'nextBusCode'),
#  ('route', 'DAY(jamExpirationDateTime)'),
#  ('tripNum', 'WEEKDAY(jamExpirationDateTime)'),
#  ('shapeSequence', 'route'),
#  ('shapeSequence', 'shapeLat'),
#  ('shapeSequence', 'busCode'),
#  ('shapeSequence', 'gpsPointId'),
#  ('shapeSequence', 'gpsLat'),
#  ('shapeSequence', 'nextBusCode'),
#  ('shapeSequence', 'DAY(jamExpirationDateTime)'),
#  ('shapeLat', 'shapeSequence'),
#  ('shapeLat', 'busCode'),
#  ('shapeLat', 'gpsPointId'),
#  ('shapeLat', 'gpsLat'),
#  ('shapeLat', 'alertLatitude'),
#  ('shapeLat', 'alertIsJamUnifiedAlert'),
#  ('shapeLat', 'alertInScale'),
#  ('shapeLat', 'nextBusCode'),
#  ('shapeLat', 'MONTH(jamExpirationDateTime)'),
#  ('shapeLon', 'route'),
#  ('shapeLon', 'busCode'),
#  ('shapeLon', 'gpsPointId'),
#  ('shapeLon', 'gpsLon'),
#  ('shapeLon', 'stopPointId'),
#  ('shapeLon', 'alertLongitude'),
#  ('shapeLon', 'nextBusCode'),
#  ('shapeLon', 'MONTH(jamExpirationDateTime)'),
#  ('distanceTraveledShape', 'DAY(jamExpirationDateTime)'),
#  ('distanceTraveledShape', 'YEAR(jamExpirationDateTime)'),
#  ('busCode', 'route'),
#  ('busCode', 'shapeSequence'),
#  ('busCode', 'shapeLat'),
#  ('busCode', 'shapeLon'),
#  ('busCode', 'gpsPointId'),
#  ('busCode', 'gpsLat'),
#  ('busCode', 'gpsLon'),
#  ('busCode', 'stopPointId'),
#  ('busCode', 'alertLongitude'),
#  ('busCode', 'nextBusCode'),
#  ('busCode', 'MONTH(jamExpirationDateTime)'),
#  ('gpsPointId', 'route'),
#  ('gpsPointId', 'shapeSequence'),
#  ('gpsPointId', 'shapeLat'),
#  ('gpsPointId', 'shapeLon'),
#  ('gpsPointId', 'busCode'),
#  ('gpsPointId', 'gpsLat'),
#  ('gpsPointId', 'gpsLon'),
#  ('gpsPointId', 'alertLongitude'),
#  ('gpsPointId', 'alertIsJamUnifiedAlert'),
#  ('gpsPointId', 'nextBusCode'),
#  ('gpsPointId', 'MONTH(jamExpirationDateTime)'),
#  ('gpsLat', 'shapeSequence'),
#  ('gpsLat', 'shapeLat'),
#  ('gpsLat', 'busCode'),
#  ('gpsLat', 'gpsPointId'),
#  ('gpsLat', 'alertLatitude'),
#  ('gpsLat', 'alertIsJamUnifiedAlert'),
#  ('gpsLat', 'alertInScale'),
#  ('gpsLat', 'nextBusCode'),
#  ('gpsLon', 'route'),
#  ('gpsLon', 'shapeLon'),
#  ('gpsLon', 'busCode'),
#  ('gpsLon', 'gpsPointId'),
#  ('gpsLon', 'stopPointId'),
#  ('gpsLon', 'alertLongitude'),
#  ('gpsLon', 'nextBusCode'),
#  ('gpsLon', 'MONTH(jamExpirationDateTime)'),
#  ('distanceToShapePoint', 'WEEKDAY(jamExpirationDateTime)'),
#  ('stopPointId', 'shapeLon'),
#  ('stopPointId', 'busCode'),
#  ('stopPointId', 'gpsLon'),
#  ('stopPointId', 'nextBusCode'),
#  ('alertRoadType', 'alertInScale'),
#  ('alertRoadType', 'DAY(jamExpirationDateTime)'),
#  ('alertRoadType', 'YEAR(jamExpirationDateTime)'),
#  ('alertConfidence', 'alertNComments'),
#  ('alertConfidence', 'alertNThumbsUp'),
#  ('alertConfidence', 'alertReliability'),
#  ('alertNComments', 'alertConfidence'),
#  ('alertNComments', 'alertReliability'),
#  ('alertNThumbsUp', 'alertConfidence'),
#  ('alertNThumbsUp', 'alertReliability'),
#  ('alertReliability', 'alertConfidence'),
#  ('alertReliability', 'alertNComments'),
#  ('alertReliability', 'alertNThumbsUp'),
#  ('alertLatitude', 'shapeLat'),
#  ('alertLatitude', 'gpsLat'),
#  ('alertLongitude', 'shapeLon'),
#  ('alertLongitude', 'busCode'),
#  ('alertLongitude', 'gpsPointId'),
#  ('alertLongitude', 'gpsLon'),
#  ('alertLongitude', 'nextBusCode'),
#  ('alertLongitude', 'MONTH(jamExpirationDateTime)'),
#  ('alertIsJamUnifiedAlert', 'shapeLat'),
#  ('alertIsJamUnifiedAlert', 'gpsPointId'),
#  ('alertIsJamUnifiedAlert', 'gpsLat'),
#  ('alertIsJamUnifiedAlert', 'alertInScale'),
#  ('alertIsJamUnifiedAlert', 'DAY(jamUpdateDateTime)'),
#  ('alertIsJamUnifiedAlert', 'MONTH(jamExpirationDateTime)'),
#  ('alertInScale', 'shapeLat'),
#  ('alertInScale', 'gpsLat'),
#  ('alertInScale', 'alertRoadType'),
#  ('alertInScale', 'alertIsJamUnifiedAlert'),
#  ('alertInScale', 'DAY(jamUpdateDateTime)'),
#  ('alertInScale', 'MONTH(jamExpirationDateTime)'),
#  ('jamDelay', 'jamLength'),
#  ('jamDelay', 'jamLevel'),
#  ('jamDelay', 'jamSeverity'),
#  ('jamLength', 'jamDelay'),
#  ('jamLength', 'jamSeverity'),
#  ('jamLength', 'jamSpeedKM'),
#  ('jamLength', 'DAY(jamExpirationDateTime)'),
#  ('jamLength', 'YEAR(jamExpirationDateTime)'),
#  ('jamLevel', 'jamDelay'),
#  ('jamLevel', 'jamSeverity'),
#  ('jamSeverity', 'jamDelay'),
#  ('jamSeverity', 'jamLength'),
#  ('jamSeverity', 'jamLevel'),
#  ('jamSeverity', 'DAY(jamExpirationDateTime)'),
#  ('jamSpeedKM', 'jamLength'),
#  ('headway', 'DAY(jamExpirationDateTime)'),
#  ('headway', 'YEAR(jamExpirationDateTime)'),
#  ('nextBusCode', 'route'),
#  ('nextBusCode', 'shapeSequence'),
#  ('nextBusCode', 'shapeLat'),
#  ('nextBusCode', 'shapeLon'),
#  ('nextBusCode', 'busCode'),
#  ('nextBusCode', 'gpsPointId'),
#  ('nextBusCode', 'gpsLat'),
#  ('nextBusCode', 'gpsLon'),
#  ('nextBusCode', 'stopPointId'),
#  ('nextBusCode', 'alertLongitude'),
#  ('nextBusCode', 'MONTH(jamExpirationDateTime)'),
#  ('DAY(gps_datetime)', 'DAY(alertDateTime)'),
#  ('DAY(gps_datetime)', 'DAY(jamUpdateDateTime)'),
#  ('DAY(gps_datetime)', 'MONTH(jamExpirationDateTime)'),
#  ('DAY(alertDateTime)', 'DAY(gps_datetime)'),
#  ('DAY(alertDateTime)', 'DAY(jamUpdateDateTime)'),
#  ('DAY(alertDateTime)', 'MONTH(jamExpirationDateTime)'),
#  ('DAY(jamUpdateDateTime)', 'alertIsJamUnifiedAlert'),
#  ('DAY(jamUpdateDateTime)', 'alertInScale'),
#  ('DAY(jamUpdateDateTime)', 'DAY(gps_datetime)'),
#  ('DAY(jamUpdateDateTime)', 'DAY(alertDateTime)'),
#  ('DAY(jamUpdateDateTime)', 'MONTH(jamExpirationDateTime)'),
#  ('DAY(jamExpirationDateTime)', 'route'),
#  ('DAY(jamExpirationDateTime)', 'shapeSequence'),
#  ('DAY(jamExpirationDateTime)', 'distanceTraveledShape'),
#  ('DAY(jamExpirationDateTime)', 'alertRoadType'),
#  ('DAY(jamExpirationDateTime)', 'jamLength'),
#  ('DAY(jamExpirationDateTime)', 'jamSeverity'),
#  ('DAY(jamExpirationDateTime)', 'headway'),
#  ('DAY(jamExpirationDateTime)', 'YEAR(jamExpirationDateTime)'),
#  ('DAY(jamExpirationDateTime)', 'WEEKDAY(jamExpirationDateTime)'),
#  ('YEAR(jamExpirationDateTime)', 'distanceTraveledShape'),
#  ('YEAR(jamExpirationDateTime)', 'alertRoadType'),
#  ('YEAR(jamExpirationDateTime)', 'jamLength'),
#  ('YEAR(jamExpirationDateTime)', 'headway'),
#  ('YEAR(jamExpirationDateTime)', 'DAY(jamExpirationDateTime)'),
#  ('YEAR(jamExpirationDateTime)', 'WEEKDAY(gps_datetime)'),
#  ('YEAR(jamExpirationDateTime)', 'WEEKDAY(alertDateTime)'),
#  ('YEAR(jamExpirationDateTime)', 'WEEKDAY(jamUpdateDateTime)'),
#  ('MONTH(jamExpirationDateTime)', 'shapeLat'),
#  ('MONTH(jamExpirationDateTime)', 'shapeLon'),
#  ('MONTH(jamExpirationDateTime)', 'busCode'),
#  ('MONTH(jamExpirationDateTime)', 'gpsPointId'),
#  ('MONTH(jamExpirationDateTime)', 'gpsLon'),
#  ('MONTH(jamExpirationDateTime)', 'alertLongitude'),
#  ('MONTH(jamExpirationDateTime)', 'alertIsJamUnifiedAlert'),
#  ('MONTH(jamExpirationDateTime)', 'alertInScale'),
#  ('MONTH(jamExpirationDateTime)', 'nextBusCode'),
#  ('MONTH(jamExpirationDateTime)', 'DAY(gps_datetime)'),
#  ('MONTH(jamExpirationDateTime)', 'DAY(alertDateTime)'),
#  ('MONTH(jamExpirationDateTime)', 'DAY(jamUpdateDateTime)'),
#  ('WEEKDAY(gps_datetime)', 'YEAR(jamExpirationDateTime)'),
#  ('WEEKDAY(gps_datetime)', 'WEEKDAY(alertDateTime)'),
#  ('WEEKDAY(gps_datetime)', 'WEEKDAY(jamUpdateDateTime)'),
#  ('WEEKDAY(gps_datetime)', 'WEEKDAY(jamExpirationDateTime)'),
#  ('WEEKDAY(alertDateTime)', 'YEAR(jamExpirationDateTime)'),
#  ('WEEKDAY(alertDateTime)', 'WEEKDAY(gps_datetime)'),
#  ('WEEKDAY(alertDateTime)', 'WEEKDAY(jamUpdateDateTime)'),
#  ('WEEKDAY(alertDateTime)', 'WEEKDAY(jamExpirationDateTime)'),
#  ('WEEKDAY(jamUpdateDateTime)', 'YEAR(jamExpirationDateTime)'),
#  ('WEEKDAY(jamUpdateDateTime)', 'WEEKDAY(gps_datetime)'),
#  ('WEEKDAY(jamUpdateDateTime)', 'WEEKDAY(alertDateTime)'),
#  ('WEEKDAY(jamUpdateDateTime)', 'WEEKDAY(jamExpirationDateTime)'),
#  ('WEEKDAY(jamExpirationDateTime)', 'tripNum'),
#  ('WEEKDAY(jamExpirationDateTime)', 'distanceToShapePoint'),
#  ('WEEKDAY(jamExpirationDateTime)', 'DAY(jamExpirationDateTime)'),
#  ('WEEKDAY(jamExpirationDateTime)', 'WEEKDAY(gps_datetime)'),
#  ('WEEKDAY(jamExpirationDateTime)', 'WEEKDAY(alertDateTime)'),
#  ('WEEKDAY(jamExpirationDateTime)', 'WEEKDAY(jamUpdateDateTime)')]

# %% [markdown]
# ## Spearman
#
# The Spearman correlation coefficient is a approach that measures the dependence (linear or non-linear) between two variables. The correlation coefficient ranges from -1 to 1.
# * 1: total positive correlation
# * -1: total negative correlation
# * 0: no correlation

# %%
spearman_corr = df.corr(method="spearman")
spearman_corr
# Out:
#                                      route   tripNum  shapeSequence  shapeLat  \
# route                             1.000000  0.009497       0.826792  0.271360
# tripNum                           0.009497  1.000000       0.018043  0.098471
# shapeSequence                     0.826792  0.018043       1.000000  0.308156
# shapeLat                          0.271360  0.098471       0.308156  1.000000
# shapeLon                          0.560993 -0.046828       0.408359  0.271045
# distanceTraveledShape             0.019749 -0.102353       0.050083 -0.066226
# busCode                           0.642498  0.074609       0.512678  0.477631
# gpsPointId                        0.554102  0.127726       0.443973  0.402827
# gpsLat                            0.269424  0.119333       0.294984  0.999934
# gpsLon                            0.530320 -0.015047       0.417348  0.233729
# distanceToShapePoint             -0.071695 -0.034109      -0.039283 -0.077445
# stopPointId                       0.183425 -0.024756       0.052730 -0.050585
# alertRoadType                    -0.134903 -0.010412      -0.131731  0.123492
# alertConfidence                  -0.010719  0.006016      -0.015538 -0.047887
# alertNComments                   -0.018545  0.002002      -0.025722  0.003289
# alertNImages                      0.023183 -0.001916       0.023836 -0.015745
# alertNThumbsUp                   -0.010667  0.009212      -0.017748 -0.015058
# alertReliability                 -0.020649  0.010772      -0.029874 -0.002069
# alertReportMood                  -0.014128  0.016399      -0.014914  0.059031
# alertReportRating                -0.018982  0.001367      -0.014632 -0.037930
# alertSpeed                             NaN       NaN            NaN       NaN
# alertLatitude                    -0.240130  0.011012      -0.236724  0.997022
# alertLongitude                    0.260531  0.011623       0.253925 -0.425476
# alertDistanceToClosestShapePoint  0.031708  0.016657       0.041781  0.185792
# alertIsJamUnifiedAlert            0.160145  0.089214       0.237294  0.659020
# alertInScale                      0.131081  0.083614       0.205662  0.650213
# jamDelay                         -0.043490  0.030644      -0.048498 -0.008801
# jamLength                         0.018202 -0.001502       0.008897 -0.095225
# jamLevel                         -0.036154  0.017481      -0.038001  0.005229
# jamSeverity                      -0.011181  0.053037      -0.014237 -0.068026
# jamSpeedKM                        0.036702 -0.054233       0.032620 -0.101665
# jamDistanceToClosestShapePoint    0.035692 -0.039140       0.050100  0.152828
# headway                           0.221897  0.000724       0.226776  0.117718
# busBunching                      -0.117799 -0.009397      -0.116433 -0.068425
# nextBusCode                       0.642908  0.075772       0.511218  0.476927
# DAY(gps_datetime)                 0.008238 -0.053125       0.005220 -0.003138
# DAY(alertDateTime)                0.003495 -0.074075      -0.001595 -0.056662
# DAY(jamUpdateDateTime)           -0.005298 -0.062518      -0.008751 -0.053314
# DAY(jamExpirationDateTime)        0.222751  0.021409       0.220311 -0.519289
# YEAR(gps_datetime)                     NaN       NaN            NaN       NaN
# YEAR(alertDateTime)                    NaN       NaN            NaN       NaN
# YEAR(jamUpdateDateTime)                NaN       NaN            NaN       NaN
# YEAR(jamExpirationDateTime)      -0.074574 -0.246400      -0.023563 -0.452335
# MONTH(gps_datetime)                    NaN       NaN            NaN       NaN
# MONTH(alertDateTime)             -0.029595  0.003092      -0.030288  0.011466
# MONTH(jamUpdateDateTime)               NaN       NaN            NaN       NaN
# MONTH(jamExpirationDateTime)      0.095203  0.235521       0.041172  0.448277
# WEEKDAY(gps_datetime)            -0.028028  0.023936      -0.004206 -0.006487
# WEEKDAY(alertDateTime)            0.029346  0.079689       0.033868  0.027846
# WEEKDAY(jamUpdateDateTime)        0.013195  0.063677       0.019074  0.056990
# WEEKDAY(jamExpirationDateTime)    0.132546  0.335425       0.116393 -0.141395
#
#                                   shapeLon  distanceTraveledShape   busCode  \
# route                             0.560993               0.019749  0.642498
# tripNum                          -0.046828              -0.102353  0.074609
# shapeSequence                     0.408359               0.050083  0.512678
# shapeLat                          0.271045              -0.066226  0.477631
# shapeLon                          1.000000               0.128792  0.685721
# distanceTraveledShape             0.128792               1.000000 -0.011609
# busCode                           0.685721              -0.011609  1.000000
# gpsPointId                        0.585414              -0.033952  0.877708
# gpsLat                            0.233881              -0.088207  0.484679
# gpsLon                            0.999920               0.099315  0.658494
# distanceToShapePoint             -0.038965              -0.005503 -0.137774
# stopPointId                       0.454302               0.047909  0.319528
# alertRoadType                    -0.239123              -0.011163 -0.167202
# alertConfidence                   0.068125               0.025074  0.041063
# alertNComments                   -0.012449               0.012075 -0.017010
# alertNImages                     -0.001577               0.013023 -0.007760
# alertNThumbsUp                    0.070549               0.014607  0.057649
# alertReliability                  0.036628               0.012350  0.027113
# alertReportMood                  -0.064231              -0.052028 -0.022055
# alertReportRating                 0.044525               0.016723  0.009050
# alertSpeed                             NaN                    NaN       NaN
# alertLatitude                    -0.427957              -0.127045  0.067195
# alertLongitude                    0.998418               0.092684  0.567211
# alertDistanceToClosestShapePoint -0.022970              -0.077340  0.033311
# alertIsJamUnifiedAlert            0.194744              -0.012908  0.277631
# alertInScale                      0.141895              -0.019591  0.234367
# jamDelay                         -0.018764               0.007506 -0.013496
# jamLength                         0.025367               0.003387 -0.017390
# jamLevel                         -0.001495               0.015685  0.021192
# jamSeverity                       0.030027               0.025980  0.001398
# jamSpeedKM                        0.017820              -0.002523 -0.035647
# jamDistanceToClosestShapePoint   -0.089108               0.006202  0.008431
# headway                           0.114905               0.006970  0.153798
# busBunching                      -0.075029               0.021418 -0.104177
# nextBusCode                       0.685946              -0.012608  0.959394
# DAY(gps_datetime)                 0.003480              -0.001450 -0.003312
# DAY(alertDateTime)               -0.013400              -0.003239 -0.054047
# DAY(jamUpdateDateTime)           -0.012143               0.000639 -0.043005
# DAY(jamExpirationDateTime)       -0.495047               0.399498 -0.518206
# YEAR(gps_datetime)                     NaN                    NaN       NaN
# YEAR(alertDateTime)                    NaN                    NaN       NaN
# YEAR(jamUpdateDateTime)                NaN                    NaN       NaN
# YEAR(jamExpirationDateTime)      -0.503349               0.350190 -0.581246
# MONTH(gps_datetime)                    NaN                    NaN       NaN
# MONTH(alertDateTime)             -0.028008              -0.015784 -0.042330
# MONTH(jamUpdateDateTime)               NaN                    NaN       NaN
# MONTH(jamExpirationDateTime)      0.506209              -0.354601  0.582202
# WEEKDAY(gps_datetime)            -0.040123               0.003864 -0.017043
# WEEKDAY(alertDateTime)            0.023187               0.002659  0.053783
# WEEKDAY(jamUpdateDateTime)       -0.004845              -0.004128  0.037563
# WEEKDAY(jamExpirationDateTime)   -0.322954               0.182527 -0.200763
#
#                                   gpsPointId    gpsLat    gpsLon  ...  \
# route                               0.554102  0.269424  0.530320  ...
# tripNum                             0.127726  0.119333 -0.015047  ...
# shapeSequence                       0.443973  0.294984  0.417348  ...
# shapeLat                            0.402827  0.999934  0.233729  ...
# shapeLon                            0.585414  0.233881  0.999920  ...
# distanceTraveledShape              -0.033952 -0.088207  0.099315  ...
# busCode                             0.877708  0.484679  0.658494  ...
# gpsPointId                          1.000000  0.402941  0.585167  ...
# gpsLat                              0.402941  1.000000  0.233706  ...
# gpsLon                              0.585167  0.233706  1.000000  ...
# distanceToShapePoint               -0.133975 -0.077675 -0.039359  ...
# stopPointId                         0.210565 -0.056489  0.386735  ...
# alertRoadType                      -0.136747  0.132569 -0.240747  ...
# alertConfidence                     0.026266 -0.029307  0.053548  ...
# alertNComments                     -0.018606  0.004302 -0.007144  ...
# alertNImages                        0.008020 -0.005199  0.006270  ...
# alertNThumbsUp                      0.029910 -0.005972  0.062577  ...
# alertReliability                   -0.001168  0.004662  0.036202  ...
# alertReportMood                    -0.019681  0.063560 -0.071359  ...
# alertReportRating                   0.014772 -0.036592  0.043717  ...
# alertSpeed                               NaN       NaN       NaN  ...
# alertLatitude                       0.097300  0.997054 -0.430511  ...
# alertLongitude                      0.444587 -0.428097  0.998446  ...
# alertDistanceToClosestShapePoint   -0.011641  0.162045 -0.018711  ...
# alertIsJamUnifiedAlert              0.291312  0.647977  0.169599  ...
# alertInScale                        0.251271  0.641882  0.118769  ...
# jamDelay                            0.107283 -0.001186 -0.016182  ...
# jamLength                           0.097124 -0.084373  0.012578  ...
# jamLevel                            0.113461  0.019453  0.005058  ...
# jamSeverity                         0.147365 -0.051276  0.019610  ...
# jamSpeedKM                         -0.007434 -0.092833 -0.000715  ...
# jamDistanceToClosestShapePoint     -0.046499  0.127534 -0.092877  ...
# headway                             0.044753  0.123977  0.063392  ...
# busBunching                        -0.046087 -0.069398 -0.061460  ...
# nextBusCode                         0.832459  0.484601  0.658365  ...
# DAY(gps_datetime)                   0.136278 -0.016218  0.005778  ...
# DAY(alertDateTime)                  0.064039 -0.051346 -0.016161  ...
# DAY(jamUpdateDateTime)              0.154748 -0.053374 -0.012336  ...
# DAY(jamExpirationDateTime)         -0.150871 -0.451938 -0.361532  ...
# YEAR(gps_datetime)                       NaN       NaN       NaN  ...
# YEAR(alertDateTime)                      NaN       NaN       NaN  ...
# YEAR(jamUpdateDateTime)                  NaN       NaN       NaN  ...
# YEAR(jamExpirationDateTime)        -0.447883 -0.375072 -0.444743  ...
# MONTH(gps_datetime)                      NaN       NaN       NaN  ...
# MONTH(alertDateTime)               -0.018328  0.005750 -0.027154  ...
# MONTH(jamUpdateDateTime)                 NaN       NaN       NaN  ...
# MONTH(jamExpirationDateTime)        0.447097  0.374140  0.445858  ...
# WEEKDAY(gps_datetime)              -0.308081  0.014313 -0.033706  ...
# WEEKDAY(alertDateTime)             -0.275593  0.041172  0.011696  ...
# WEEKDAY(jamUpdateDateTime)         -0.312188  0.064130 -0.009373  ...
# WEEKDAY(jamExpirationDateTime)     -0.183467  0.030770 -0.244107  ...
#
#                                   YEAR(jamUpdateDateTime)  \
# route                                                 NaN
# tripNum                                               NaN
# shapeSequence                                         NaN
# shapeLat                                              NaN
# shapeLon                                              NaN
# distanceTraveledShape                                 NaN
# busCode                                               NaN
# gpsPointId                                            NaN
# gpsLat                                                NaN
# gpsLon                                                NaN
# distanceToShapePoint                                  NaN
# stopPointId                                           NaN
# alertRoadType                                         NaN
# alertConfidence                                       NaN
# alertNComments                                        NaN
# alertNImages                                          NaN
# alertNThumbsUp                                        NaN
# alertReliability                                      NaN
# alertReportMood                                       NaN
# alertReportRating                                     NaN
# alertSpeed                                            NaN
# alertLatitude                                         NaN
# alertLongitude                                        NaN
# alertDistanceToClosestShapePoint                      NaN
# alertIsJamUnifiedAlert                                NaN
# alertInScale                                          NaN
# jamDelay                                              NaN
# jamLength                                             NaN
# jamLevel                                              NaN
# jamSeverity                                           NaN
# jamSpeedKM                                            NaN
# jamDistanceToClosestShapePoint                        NaN
# headway                                               NaN
# busBunching                                           NaN
# nextBusCode                                           NaN
# DAY(gps_datetime)                                     NaN
# DAY(alertDateTime)                                    NaN
# DAY(jamUpdateDateTime)                                NaN
# DAY(jamExpirationDateTime)                            NaN
# YEAR(gps_datetime)                                    NaN
# YEAR(alertDateTime)                                   NaN
# YEAR(jamUpdateDateTime)                               NaN
# YEAR(jamExpirationDateTime)                           NaN
# MONTH(gps_datetime)                                   NaN
# MONTH(alertDateTime)                                  NaN
# MONTH(jamUpdateDateTime)                              NaN
# MONTH(jamExpirationDateTime)                          NaN
# WEEKDAY(gps_datetime)                                 NaN
# WEEKDAY(alertDateTime)                                NaN
# WEEKDAY(jamUpdateDateTime)                            NaN
# WEEKDAY(jamExpirationDateTime)                        NaN
#
#                                   YEAR(jamExpirationDateTime)  \
# route                                               -0.074574
# tripNum                                             -0.246400
# shapeSequence                                       -0.023563
# shapeLat                                            -0.452335
# shapeLon                                            -0.503349
# distanceTraveledShape                                0.350190
# busCode                                             -0.581246
# gpsPointId                                          -0.447883
# gpsLat                                              -0.375072
# gpsLon                                              -0.444743
# distanceToShapePoint                                 0.198012
# stopPointId                                          0.019747
# alertRoadType                                        0.368891
# alertConfidence                                      0.104450
# alertNComments                                       0.177159
# alertNImages                                              NaN
# alertNThumbsUp                                       0.084562
# alertReliability                                     0.263299
# alertReportMood                                      0.053035
# alertReportRating                                   -0.187482
# alertSpeed                                                NaN
# alertLatitude                                       -0.455097
# alertLongitude                                      -0.572845
# alertDistanceToClosestShapePoint                     0.030340
# alertIsJamUnifiedAlert                              -0.578153
# alertInScale                                        -0.407395
# jamDelay                                                  NaN
# jamLength                                            0.419013
# jamLevel                                                  NaN
# jamSeverity                                          0.046215
# jamSpeedKM                                                NaN
# jamDistanceToClosestShapePoint                      -0.048450
# headway                                              0.094741
# busBunching                                         -0.055363
# nextBusCode                                         -0.582940
# DAY(gps_datetime)                                   -0.562850
# DAY(alertDateTime)                                  -0.605109
# DAY(jamUpdateDateTime)                              -0.562850
# DAY(jamExpirationDateTime)                           0.656577
# YEAR(gps_datetime)                                        NaN
# YEAR(alertDateTime)                                       NaN
# YEAR(jamUpdateDateTime)                                   NaN
# YEAR(jamExpirationDateTime)                          1.000000
# MONTH(gps_datetime)                                       NaN
# MONTH(alertDateTime)                                      NaN
# MONTH(jamUpdateDateTime)                                  NaN
# MONTH(jamExpirationDateTime)                        -0.997797
# WEEKDAY(gps_datetime)                                0.349643
# WEEKDAY(alertDateTime)                               0.473557
# WEEKDAY(jamUpdateDateTime)                           0.349643
# WEEKDAY(jamExpirationDateTime)                       0.326022
#
#                                   MONTH(gps_datetime)  MONTH(alertDateTime)  \
# route                                             NaN             -0.029595
# tripNum                                           NaN              0.003092
# shapeSequence                                     NaN             -0.030288
# shapeLat                                          NaN              0.011466
# shapeLon                                          NaN             -0.028008
# distanceTraveledShape                             NaN             -0.015784
# busCode                                           NaN             -0.042330
# gpsPointId                                        NaN             -0.018328
# gpsLat                                            NaN              0.005750
# gpsLon                                            NaN             -0.027154
# distanceToShapePoint                              NaN              0.000006
# stopPointId                                       NaN             -0.000558
# alertRoadType                                     NaN              0.006757
# alertConfidence                                   NaN             -0.094252
# alertNComments                                    NaN             -0.073836
# alertNImages                                      NaN              0.002810
# alertNThumbsUp                                    NaN             -0.085636
# alertReliability                                  NaN             -0.068271
# alertReportMood                                   NaN              0.041044
# alertReportRating                                 NaN              0.010061
# alertSpeed                                        NaN                   NaN
# alertLatitude                                     NaN              0.011871
# alertLongitude                                    NaN             -0.027643
# alertDistanceToClosestShapePoint                  NaN             -0.008394
# alertIsJamUnifiedAlert                            NaN                   NaN
# alertInScale                                      NaN              0.014232
# jamDelay                                          NaN              0.008392
# jamLength                                         NaN             -0.010930
# jamLevel                                          NaN              0.014004
# jamSeverity                                       NaN             -0.001746
# jamSpeedKM                                        NaN             -0.013145
# jamDistanceToClosestShapePoint                    NaN             -0.013993
# headway                                           NaN             -0.016996
# busBunching                                       NaN              0.004894
# nextBusCode                                       NaN             -0.041957
# DAY(gps_datetime)                                 NaN              0.063031
# DAY(alertDateTime)                                NaN             -0.098226
# DAY(jamUpdateDateTime)                            NaN              0.064589
# DAY(jamExpirationDateTime)                        NaN                   NaN
# YEAR(gps_datetime)                                NaN                   NaN
# YEAR(alertDateTime)                               NaN                   NaN
# YEAR(jamUpdateDateTime)                           NaN                   NaN
# YEAR(jamExpirationDateTime)                       NaN                   NaN
# MONTH(gps_datetime)                               NaN                   NaN
# MONTH(alertDateTime)                              NaN              1.000000
# MONTH(jamUpdateDateTime)                          NaN                   NaN
# MONTH(jamExpirationDateTime)                      NaN                   NaN
# WEEKDAY(gps_datetime)                             NaN             -0.010727
# WEEKDAY(alertDateTime)                            NaN              0.005761
# WEEKDAY(jamUpdateDateTime)                        NaN             -0.008317
# WEEKDAY(jamExpirationDateTime)                    NaN                   NaN
#
#                                   MONTH(jamUpdateDateTime)  \
# route                                                  NaN
# tripNum                                                NaN
# shapeSequence                                          NaN
# shapeLat                                               NaN
# shapeLon                                               NaN
# distanceTraveledShape                                  NaN
# busCode                                                NaN
# gpsPointId                                             NaN
# gpsLat                                                 NaN
# gpsLon                                                 NaN
# distanceToShapePoint                                   NaN
# stopPointId                                            NaN
# alertRoadType                                          NaN
# alertConfidence                                        NaN
# alertNComments                                         NaN
# alertNImages                                           NaN
# alertNThumbsUp                                         NaN
# alertReliability                                       NaN
# alertReportMood                                        NaN
# alertReportRating                                      NaN
# alertSpeed                                             NaN
# alertLatitude                                          NaN
# alertLongitude                                         NaN
# alertDistanceToClosestShapePoint                       NaN
# alertIsJamUnifiedAlert                                 NaN
# alertInScale                                           NaN
# jamDelay                                               NaN
# jamLength                                              NaN
# jamLevel                                               NaN
# jamSeverity                                            NaN
# jamSpeedKM                                             NaN
# jamDistanceToClosestShapePoint                         NaN
# headway                                                NaN
# busBunching                                            NaN
# nextBusCode                                            NaN
# DAY(gps_datetime)                                      NaN
# DAY(alertDateTime)                                     NaN
# DAY(jamUpdateDateTime)                                 NaN
# DAY(jamExpirationDateTime)                             NaN
# YEAR(gps_datetime)                                     NaN
# YEAR(alertDateTime)                                    NaN
# YEAR(jamUpdateDateTime)                                NaN
# YEAR(jamExpirationDateTime)                            NaN
# MONTH(gps_datetime)                                    NaN
# MONTH(alertDateTime)                                   NaN
# MONTH(jamUpdateDateTime)                               NaN
# MONTH(jamExpirationDateTime)                           NaN
# WEEKDAY(gps_datetime)                                  NaN
# WEEKDAY(alertDateTime)                                 NaN
# WEEKDAY(jamUpdateDateTime)                             NaN
# WEEKDAY(jamExpirationDateTime)                         NaN
#
#                                   MONTH(jamExpirationDateTime)  \
# route                                                 0.095203
# tripNum                                               0.235521
# shapeSequence                                         0.041172
# shapeLat                                              0.448277
# shapeLon                                              0.506209
# distanceTraveledShape                                -0.354601
# busCode                                               0.582202
# gpsPointId                                            0.447097
# gpsLat                                                0.374140
# gpsLon                                                0.445858
# distanceToShapePoint                                 -0.194597
# stopPointId                                          -0.044040
# alertRoadType                                        -0.400677
# alertConfidence                                      -0.143678
# alertNComments                                       -0.023497
# alertNImages                                               NaN
# alertNThumbsUp                                       -0.167122
# alertReliability                                     -0.321873
# alertReportMood                                       0.040732
# alertReportRating                                     0.114228
# alertSpeed                                                 NaN
# alertLatitude                                         0.350086
# alertLongitude                                        0.630642
# alertDistanceToClosestShapePoint                     -0.145069
# alertIsJamUnifiedAlert                                0.572794
# alertInScale                                          0.394244
# jamDelay                                                   NaN
# jamLength                                            -0.423778
# jamLevel                                                   NaN
# jamSeverity                                          -0.053030
# jamSpeedKM                                                 NaN
# jamDistanceToClosestShapePoint                        0.065750
# headway                                              -0.076460
# busBunching                                           0.052050
# nextBusCode                                           0.584093
# DAY(gps_datetime)                                     0.564665
# DAY(alertDateTime)                                    0.575352
# DAY(jamUpdateDateTime)                                0.564665
# DAY(jamExpirationDateTime)                           -0.658027
# YEAR(gps_datetime)                                         NaN
# YEAR(alertDateTime)                                        NaN
# YEAR(jamUpdateDateTime)                                    NaN
# YEAR(jamExpirationDateTime)                          -0.997797
# MONTH(gps_datetime)                                        NaN
# MONTH(alertDateTime)                                       NaN
# MONTH(jamUpdateDateTime)                                   NaN
# MONTH(jamExpirationDateTime)                          1.000000
# WEEKDAY(gps_datetime)                                -0.344942
# WEEKDAY(alertDateTime)                               -0.453015
# WEEKDAY(jamUpdateDateTime)                           -0.344942
# WEEKDAY(jamExpirationDateTime)                       -0.325303
#
#                                   WEEKDAY(gps_datetime)  \
# route                                         -0.028028
# tripNum                                        0.023936
# shapeSequence                                 -0.004206
# shapeLat                                      -0.006487
# shapeLon                                      -0.040123
# distanceTraveledShape                          0.003864
# busCode                                       -0.017043
# gpsPointId                                    -0.308081
# gpsLat                                         0.014313
# gpsLon                                        -0.033706
# distanceToShapePoint                          -0.000373
# stopPointId                                   -0.051201
# alertRoadType                                 -0.020820
# alertConfidence                                0.001878
# alertNComments                                -0.004040
# alertNImages                                   0.002076
# alertNThumbsUp                                 0.037376
# alertReliability                               0.049176
# alertReportMood                                0.037990
# alertReportRating                             -0.028718
# alertSpeed                                          NaN
# alertLatitude                                  0.030899
# alertLongitude                                 0.013104
# alertDistanceToClosestShapePoint               0.111020
# alertIsJamUnifiedAlert                        -0.124451
# alertInScale                                  -0.113409
# jamDelay                                      -0.221714
# jamLength                                     -0.269091
# jamLevel                                      -0.139014
# jamSeverity                                   -0.302185
# jamSpeedKM                                    -0.122028
# jamDistanceToClosestShapePoint                 0.120990
# headway                                        0.163716
# busBunching                                   -0.083418
# nextBusCode                                   -0.017355
# DAY(gps_datetime)                             -0.494217
# DAY(alertDateTime)                            -0.403644
# DAY(jamUpdateDateTime)                        -0.498890
# DAY(jamExpirationDateTime)                     0.264804
# YEAR(gps_datetime)                                  NaN
# YEAR(alertDateTime)                                 NaN
# YEAR(jamUpdateDateTime)                             NaN
# YEAR(jamExpirationDateTime)                    0.349643
# MONTH(gps_datetime)                                 NaN
# MONTH(alertDateTime)                          -0.010727
# MONTH(jamUpdateDateTime)                            NaN
# MONTH(jamExpirationDateTime)                  -0.344942
# WEEKDAY(gps_datetime)                          1.000000
# WEEKDAY(alertDateTime)                         0.966153
# WEEKDAY(jamUpdateDateTime)                     0.999875
# WEEKDAY(jamExpirationDateTime)                 0.427223
#
#                                   WEEKDAY(alertDateTime)  \
# route                                           0.029346
# tripNum                                         0.079689
# shapeSequence                                   0.033868
# shapeLat                                        0.027846
# shapeLon                                        0.023187
# distanceTraveledShape                           0.002659
# busCode                                         0.053783
# gpsPointId                                     -0.275593
# gpsLat                                          0.041172
# gpsLon                                          0.011696
# distanceToShapePoint                           -0.012773
# stopPointId                                    -0.045943
# alertRoadType                                  -0.032869
# alertConfidence                                -0.015830
# alertNComments                                 -0.002906
# alertNImages                                    0.002007
# alertNThumbsUp                                  0.015012
# alertReliability                                0.033130
# alertReportMood                                 0.037091
# alertReportRating                              -0.032648
# alertSpeed                                           NaN
# alertLatitude                                   0.029635
# alertLongitude                                  0.023373
# alertDistanceToClosestShapePoint                0.110669
# alertIsJamUnifiedAlert                               NaN
# alertInScale                                    0.020416
# jamDelay                                       -0.240789
# jamLength                                      -0.274997
# jamLevel                                       -0.158354
# jamSeverity                                    -0.334601
# jamSpeedKM                                     -0.111614
# jamDistanceToClosestShapePoint                  0.118526
# headway                                         0.173362
# busBunching                                    -0.105245
# nextBusCode                                     0.053428
# DAY(gps_datetime)                              -0.387928
# DAY(alertDateTime)                             -0.385736
# DAY(jamUpdateDateTime)                         -0.375312
# DAY(jamExpirationDateTime)                      0.244358
# YEAR(gps_datetime)                                   NaN
# YEAR(alertDateTime)                                  NaN
# YEAR(jamUpdateDateTime)                              NaN
# YEAR(jamExpirationDateTime)                     0.473557
# MONTH(gps_datetime)                                  NaN
# MONTH(alertDateTime)                            0.005761
# MONTH(jamUpdateDateTime)                             NaN
# MONTH(jamExpirationDateTime)                   -0.453015
# WEEKDAY(gps_datetime)                           0.966153
# WEEKDAY(alertDateTime)                          1.000000
# WEEKDAY(jamUpdateDateTime)                      0.968297
# WEEKDAY(jamExpirationDateTime)                  0.703930
#
#                                   WEEKDAY(jamUpdateDateTime)  \
# route                                               0.013195
# tripNum                                             0.063677
# shapeSequence                                       0.019074
# shapeLat                                            0.056990
# shapeLon                                           -0.004845
# distanceTraveledShape                              -0.004128
# busCode                                             0.037563
# gpsPointId                                         -0.312188
# gpsLat                                              0.064130
# gpsLon                                             -0.009373
# distanceToShapePoint                               -0.010821
# stopPointId                                        -0.042655
# alertRoadType                                      -0.005647
# alertConfidence                                     0.002224
# alertNComments                                      0.010354
# alertNImages                                        0.003349
# alertNThumbsUp                                      0.046142
# alertReliability                                    0.061654
# alertReportMood                                     0.045984
# alertReportRating                                  -0.032132
# alertSpeed                                               NaN
# alertLatitude                                       0.056752
# alertLongitude                                     -0.010428
# alertDistanceToClosestShapePoint                    0.143000
# alertIsJamUnifiedAlert                             -0.300845
# alertInScale                                       -0.242194
# jamDelay                                           -0.221710
# jamLength                                          -0.269143
# jamLevel                                           -0.138996
# jamSeverity                                        -0.302232
# jamSpeedKM                                         -0.122067
# jamDistanceToClosestShapePoint                      0.121007
# headway                                             0.168910
# busBunching                                        -0.099126
# nextBusCode                                         0.037142
# DAY(gps_datetime)                                  -0.498838
# DAY(alertDateTime)                                 -0.388777
# DAY(jamUpdateDateTime)                             -0.498857
# DAY(jamExpirationDateTime)                          0.264804
# YEAR(gps_datetime)                                       NaN
# YEAR(alertDateTime)                                      NaN
# YEAR(jamUpdateDateTime)                                  NaN
# YEAR(jamExpirationDateTime)                         0.349643
# MONTH(gps_datetime)                                      NaN
# MONTH(alertDateTime)                               -0.008317
# MONTH(jamUpdateDateTime)                                 NaN
# MONTH(jamExpirationDateTime)                       -0.344942
# WEEKDAY(gps_datetime)                               0.999875
# WEEKDAY(alertDateTime)                              0.968297
# WEEKDAY(jamUpdateDateTime)                          1.000000
# WEEKDAY(jamExpirationDateTime)                      0.427223
#
#                                   WEEKDAY(jamExpirationDateTime)
# route                                                   0.132546
# tripNum                                                 0.335425
# shapeSequence                                           0.116393
# shapeLat                                               -0.141395
# shapeLon                                               -0.322954
# distanceTraveledShape                                   0.182527
# busCode                                                -0.200763
# gpsPointId                                             -0.183467
# gpsLat                                                  0.030770
# gpsLon                                                 -0.244107
# distanceToShapePoint                                    0.227321
# stopPointId                                            -0.316187
# alertRoadType                                           0.167279
# alertConfidence                                        -0.160107
# alertNComments                                          0.150918
# alertNImages                                                 NaN
# alertNThumbsUp                                         -0.220258
# alertReliability                                       -0.149696
# alertReportMood                                         0.013564
# alertReportRating                                      -0.306991
# alertSpeed                                                   NaN
# alertLatitude                                          -0.134554
# alertLongitude                                         -0.488711
# alertDistanceToClosestShapePoint                        0.353544
# alertIsJamUnifiedAlert                                 -0.077110
# alertInScale                                           -0.015890
# jamDelay                                                     NaN
# jamLength                                               0.408109
# jamLevel                                                     NaN
# jamSeverity                                             0.301341
# jamSpeedKM                                                   NaN
# jamDistanceToClosestShapePoint                         -0.052919
# headway                                                 0.147702
# busBunching                                            -0.132070
# nextBusCode                                            -0.194722
# DAY(gps_datetime)                                      -0.109024
# DAY(alertDateTime)                                     -0.522571
# DAY(jamUpdateDateTime)                                 -0.109024
# DAY(jamExpirationDateTime)                              0.723572
# YEAR(gps_datetime)                                           NaN
# YEAR(alertDateTime)                                          NaN
# YEAR(jamUpdateDateTime)                                      NaN
# YEAR(jamExpirationDateTime)                             0.326022
# MONTH(gps_datetime)                                          NaN
# MONTH(alertDateTime)                                         NaN
# MONTH(jamUpdateDateTime)                                     NaN
# MONTH(jamExpirationDateTime)                           -0.325303
# WEEKDAY(gps_datetime)                                   0.427223
# WEEKDAY(alertDateTime)                                  0.703930
# WEEKDAY(jamUpdateDateTime)                              0.427223
# WEEKDAY(jamExpirationDateTime)                          1.000000
#
# [51 rows x 51 columns]

# %%
plot_corr(spearman_corr)

# %% [markdown]
# ## Kendall
#
# The Kendall correlation coefficient is a approach that measures the dependence (linear or non-linear) between two variables. The correlation coefficient ranges from -1 to 1.
# * 1: total positive correlation
# * -1: total negative correlation
# * 0: no correlation

# %%
kendall_corr = df.corr(method="kendall")
kendall_corr
# Out:
#                                      route   tripNum  shapeSequence  shapeLat  \
# route                             1.000000  0.006338       0.780585  0.164343
# tripNum                           0.006338  1.000000       0.011958  0.069033
# shapeSequence                     0.780585  0.011958       1.000000  0.197584
# shapeLat                          0.164343  0.069033       0.197584  1.000000
# shapeLon                          0.415951 -0.032809       0.313336  0.136220
# distanceTraveledShape             0.015307 -0.072035       0.039087 -0.043058
# busCode                           0.481048  0.051509       0.397159  0.322608
# gpsPointId                        0.396847  0.089949       0.320136  0.270910
# gpsLat                            0.171351  0.083721       0.194882  0.995536
# gpsLon                            0.385705 -0.010574       0.309827  0.107322
# distanceToShapePoint             -0.047548 -0.023889      -0.025999 -0.052081
# stopPointId                       0.150735 -0.016971       0.053206  0.008246
# alertRoadType                    -0.109503 -0.008728      -0.105041  0.096935
# alertConfidence                  -0.008507  0.004968      -0.012131 -0.037623
# alertNComments                   -0.015084  0.001688      -0.020554  0.002545
# alertNImages                      0.019294 -0.001651       0.019468 -0.012860
# alertNThumbsUp                   -0.008115  0.007431      -0.013327 -0.011138
# alertReliability                 -0.015711  0.008580      -0.022313 -0.001748
# alertReportMood                  -0.010148  0.012130      -0.010383  0.041406
# alertReportRating                -0.014351  0.001072      -0.010900 -0.028132
# alertSpeed                             NaN       NaN            NaN       NaN
# alertLatitude                    -0.160465  0.007657      -0.154413  0.959392
# alertLongitude                    0.196269  0.008238       0.189472 -0.294443
# alertDistanceToClosestShapePoint  0.022019  0.011708       0.028485  0.123051
# alertIsJamUnifiedAlert            0.131966  0.076447       0.193774  0.538155
# alertInScale                      0.108016  0.071649       0.167943  0.530963
# jamDelay                         -0.029802  0.022045      -0.032506 -0.007127
# jamLength                         0.012770 -0.001029       0.006137 -0.062464
# jamLevel                         -0.028337  0.014359      -0.029206  0.004479
# jamSeverity                      -0.009256  0.045158      -0.011561 -0.055447
# jamSpeedKM                        0.025288 -0.038236       0.021871 -0.068377
# jamDistanceToClosestShapePoint    0.024868 -0.027066       0.034249  0.101527
# headway                           0.149570  0.000421       0.151666  0.079189
# busBunching                      -0.097071 -0.008052      -0.095079 -0.055875
# nextBusCode                       0.481565  0.052228       0.396981  0.321980
# DAY(gps_datetime)                 0.005774 -0.039150       0.003597 -0.002264
# DAY(alertDateTime)                0.002607 -0.055364      -0.001218 -0.040167
# DAY(jamUpdateDateTime)           -0.003793 -0.046526      -0.006242 -0.037689
# DAY(jamExpirationDateTime)        0.176402  0.020085       0.166492 -0.341879
# YEAR(gps_datetime)                     NaN       NaN            NaN       NaN
# YEAR(alertDateTime)                    NaN       NaN            NaN       NaN
# YEAR(jamUpdateDateTime)                NaN       NaN            NaN       NaN
# YEAR(jamExpirationDateTime)      -0.063236 -0.212205      -0.019402 -0.372466
# MONTH(gps_datetime)                    NaN       NaN            NaN       NaN
# MONTH(alertDateTime)             -0.024630  0.002664      -0.024738  0.009365
# MONTH(jamUpdateDateTime)               NaN       NaN            NaN       NaN
# MONTH(jamExpirationDateTime)      0.076042  0.195926       0.029292  0.351802
# WEEKDAY(gps_datetime)            -0.020758  0.018256      -0.003107 -0.004846
# WEEKDAY(alertDateTime)            0.021731  0.060642       0.024527  0.020306
# WEEKDAY(jamUpdateDateTime)        0.009739  0.048622       0.013837  0.041669
# WEEKDAY(jamExpirationDateTime)    0.117887  0.274038       0.094297 -0.099169
#
#                                   shapeLon  distanceTraveledShape   busCode  \
# route                             0.415951               0.015307  0.481048
# tripNum                          -0.032809              -0.072035  0.051509
# shapeSequence                     0.313336               0.039087  0.397159
# shapeLat                          0.136220              -0.043058  0.322608
# shapeLon                          1.000000               0.086335  0.490235
# distanceTraveledShape             0.086335               1.000000 -0.006298
# busCode                           0.490235              -0.006298  1.000000
# gpsPointId                        0.407503              -0.022549  0.724682
# gpsLat                            0.107544              -0.058786  0.329694
# gpsLon                            0.995467               0.066414  0.468384
# distanceToShapePoint             -0.026132              -0.003109 -0.093592
# stopPointId                       0.313553               0.035569  0.238950
# alertRoadType                    -0.195440              -0.008874 -0.133805
# alertConfidence                   0.053227               0.019632  0.032135
# alertNComments                   -0.009710               0.009646 -0.013632
# alertNImages                     -0.001288               0.010637 -0.006347
# alertNThumbsUp                    0.054235               0.011038  0.044209
# alertReliability                  0.027618               0.009320  0.020726
# alertReportMood                  -0.045085              -0.036739 -0.015301
# alertReportRating                 0.033181               0.012353  0.006677
# alertSpeed                             NaN                    NaN       NaN
# alertLatitude                    -0.295229              -0.088136  0.046709
# alertLongitude                    0.969378               0.064238  0.403801
# alertDistanceToClosestShapePoint -0.009403              -0.051855  0.022664
# alertIsJamUnifiedAlert            0.159028              -0.010541  0.226908
# alertInScale                      0.115871              -0.015999  0.191548
# jamDelay                         -0.012120               0.004980 -0.009207
# jamLength                         0.015372               0.002312 -0.011288
# jamLevel                         -0.001503               0.011999  0.016290
# jamSeverity                       0.024410               0.021118  0.001119
# jamSpeedKM                        0.011558              -0.001906 -0.023377
# jamDistanceToClosestShapePoint   -0.058789               0.004485  0.005857
# headway                           0.077609               0.004665  0.103486
# busBunching                      -0.061269               0.017491 -0.085144
# nextBusCode                       0.490585              -0.006981  0.834880
# DAY(gps_datetime)                 0.002494              -0.001026 -0.002622
# DAY(alertDateTime)               -0.009521              -0.002324 -0.038715
# DAY(jamUpdateDateTime)           -0.008579               0.000447 -0.030565
# DAY(jamExpirationDateTime)       -0.342215               0.326294 -0.428645
# YEAR(gps_datetime)                     NaN                    NaN       NaN
# YEAR(alertDateTime)                    NaN                    NaN       NaN
# YEAR(jamUpdateDateTime)                NaN                    NaN       NaN
# YEAR(jamExpirationDateTime)      -0.414472               0.288523 -0.477833
# MONTH(gps_datetime)                    NaN                    NaN       NaN
# MONTH(alertDateTime)             -0.022876              -0.012892 -0.034624
# MONTH(jamUpdateDateTime)               NaN                    NaN       NaN
# MONTH(jamExpirationDateTime)      0.423385              -0.292020  0.482184
# WEEKDAY(gps_datetime)            -0.029191               0.002813 -0.012861
# WEEKDAY(alertDateTime)            0.016719               0.001948  0.038843
# WEEKDAY(jamUpdateDateTime)       -0.003537              -0.003011  0.027350
# WEEKDAY(jamExpirationDateTime)   -0.215701               0.150361 -0.162686
#
#                                   gpsPointId    gpsLat    gpsLon  ...  \
# route                               0.396847  0.171351  0.385705  ...
# tripNum                             0.089949  0.083721 -0.010574  ...
# shapeSequence                       0.320136  0.194882  0.309827  ...
# shapeLat                            0.270910  0.995536  0.107322  ...
# shapeLon                            0.407503  0.107544  0.995467  ...
# distanceTraveledShape              -0.022549 -0.058786  0.066414  ...
# busCode                             0.724682  0.329694  0.468384  ...
# gpsPointId                          1.000000  0.270929  0.407216  ...
# gpsLat                              0.270929  1.000000  0.106965  ...
# gpsLon                              0.407216  0.106965  1.000000  ...
# distanceToShapePoint               -0.090629 -0.052262 -0.026403  ...
# stopPointId                         0.149330  0.005630  0.258892  ...
# alertRoadType                      -0.109705  0.104803 -0.197238  ...
# alertConfidence                     0.020604 -0.023140  0.042023  ...
# alertNComments                     -0.014864  0.003212 -0.005573  ...
# alertNImages                        0.006549 -0.004245  0.005120  ...
# alertNThumbsUp                      0.022835 -0.004357  0.048123  ...
# alertReliability                   -0.000800  0.003205  0.027195  ...
# alertReportMood                    -0.013138  0.044700 -0.050352  ...
# alertReportRating                   0.010897 -0.026857  0.032360  ...
# alertSpeed                               NaN       NaN       NaN  ...
# alertLatitude                       0.066920  0.959564 -0.300379  ...
# alertLongitude                      0.307976 -0.300169  0.969094  ...
# alertDistanceToClosestShapePoint   -0.007747  0.107502 -0.006373  ...
# alertIsJamUnifiedAlert              0.237856  0.529073  0.138478  ...
# alertInScale                        0.205162  0.524096  0.096975  ...
# jamDelay                            0.072111 -0.002157 -0.010069  ...
# jamLength                           0.065591 -0.055163  0.006852  ...
# jamLevel                            0.087575  0.015315  0.003806  ...
# jamSeverity                         0.119151 -0.041814  0.016024  ...
# jamSpeedKM                         -0.004433 -0.062832 -0.000746  ...
# jamDistanceToClosestShapePoint     -0.030220  0.083979 -0.060829  ...
# headway                             0.029822  0.083252  0.043450  ...
# busBunching                        -0.037630 -0.056664 -0.050182  ...
# nextBusCode                         0.639582  0.329486  0.468599  ...
# DAY(gps_datetime)                   0.098759 -0.011549  0.004157  ...
# DAY(alertDateTime)                  0.050872 -0.036458 -0.011512  ...
# DAY(jamUpdateDateTime)              0.113201 -0.037766 -0.008734  ...
# DAY(jamExpirationDateTime)         -0.141020 -0.299708 -0.241238  ...
# YEAR(gps_datetime)                       NaN       NaN       NaN  ...
# YEAR(alertDateTime)                      NaN       NaN       NaN  ...
# YEAR(jamUpdateDateTime)                  NaN       NaN       NaN  ...
# YEAR(jamExpirationDateTime)        -0.366904 -0.307323 -0.364410  ...
# MONTH(gps_datetime)                      NaN       NaN       NaN  ...
# MONTH(alertDateTime)               -0.014965  0.004695 -0.022171  ...
# MONTH(jamUpdateDateTime)                 NaN       NaN       NaN  ...
# MONTH(jamExpirationDateTime)        0.362071  0.300300  0.367270  ...
# WEEKDAY(gps_datetime)              -0.226742  0.010319 -0.024464  ...
# WEEKDAY(alertDateTime)             -0.204290  0.030081  0.008383  ...
# WEEKDAY(jamUpdateDateTime)         -0.232211  0.046978 -0.006863  ...
# WEEKDAY(jamExpirationDateTime)     -0.155089  0.029730 -0.149748  ...
#
#                                   YEAR(jamUpdateDateTime)  \
# route                                                 NaN
# tripNum                                               NaN
# shapeSequence                                         NaN
# shapeLat                                              NaN
# shapeLon                                              NaN
# distanceTraveledShape                                 NaN
# busCode                                               NaN
# gpsPointId                                            NaN
# gpsLat                                                NaN
# gpsLon                                                NaN
# distanceToShapePoint                                  NaN
# stopPointId                                           NaN
# alertRoadType                                         NaN
# alertConfidence                                       NaN
# alertNComments                                        NaN
# alertNImages                                          NaN
# alertNThumbsUp                                        NaN
# alertReliability                                      NaN
# alertReportMood                                       NaN
# alertReportRating                                     NaN
# alertSpeed                                            NaN
# alertLatitude                                         NaN
# alertLongitude                                        NaN
# alertDistanceToClosestShapePoint                      NaN
# alertIsJamUnifiedAlert                                NaN
# alertInScale                                          NaN
# jamDelay                                              NaN
# jamLength                                             NaN
# jamLevel                                              NaN
# jamSeverity                                           NaN
# jamSpeedKM                                            NaN
# jamDistanceToClosestShapePoint                        NaN
# headway                                               NaN
# busBunching                                           NaN
# nextBusCode                                           NaN
# DAY(gps_datetime)                                     NaN
# DAY(alertDateTime)                                    NaN
# DAY(jamUpdateDateTime)                                NaN
# DAY(jamExpirationDateTime)                            NaN
# YEAR(gps_datetime)                                    NaN
# YEAR(alertDateTime)                                   NaN
# YEAR(jamUpdateDateTime)                               1.0
# YEAR(jamExpirationDateTime)                           NaN
# MONTH(gps_datetime)                                   NaN
# MONTH(alertDateTime)                                  NaN
# MONTH(jamUpdateDateTime)                              NaN
# MONTH(jamExpirationDateTime)                          NaN
# WEEKDAY(gps_datetime)                                 NaN
# WEEKDAY(alertDateTime)                                NaN
# WEEKDAY(jamUpdateDateTime)                            NaN
# WEEKDAY(jamExpirationDateTime)                        NaN
#
#                                   YEAR(jamExpirationDateTime)  \
# route                                               -0.063236
# tripNum                                             -0.212205
# shapeSequence                                       -0.019402
# shapeLat                                            -0.372466
# shapeLon                                            -0.414472
# distanceTraveledShape                                0.288523
# busCode                                             -0.477833
# gpsPointId                                          -0.366904
# gpsLat                                              -0.307323
# gpsLon                                              -0.364410
# distanceToShapePoint                                 0.162239
# stopPointId                                          0.016800
# alertRoadType                                        0.355101
# alertConfidence                                      0.100809
# alertNComments                                       0.175967
# alertNImages                                              NaN
# alertNThumbsUp                                       0.078076
# alertReliability                                     0.239757
# alertReportMood                                      0.046067
# alertReportRating                                   -0.171726
# alertSpeed                                                NaN
# alertLatitude                                       -0.379339
# alertLongitude                                      -0.477486
# alertDistanceToClosestShapePoint                     0.025289
# alertIsJamUnifiedAlert                              -0.578153
# alertInScale                                        -0.407395
# jamDelay                                                  NaN
# jamLength                                            0.380306
# jamLevel                                                  NaN
# jamSeverity                                          0.046215
# jamSpeedKM                                                NaN
# jamDistanceToClosestShapePoint                      -0.039814
# headway                                              0.078211
# busBunching                                         -0.055363
# nextBusCode                                         -0.479509
# DAY(gps_datetime)                                   -0.538825
# DAY(alertDateTime)                                  -0.547613
# DAY(jamUpdateDateTime)                              -0.538825
# DAY(jamExpirationDateTime)                           0.598872
# YEAR(gps_datetime)                                        NaN
# YEAR(alertDateTime)                                       NaN
# YEAR(jamUpdateDateTime)                                   NaN
# YEAR(jamExpirationDateTime)                          1.000000
# MONTH(gps_datetime)                                       NaN
# MONTH(alertDateTime)                                      NaN
# MONTH(jamUpdateDateTime)                                  NaN
# MONTH(jamExpirationDateTime)                        -0.985068
# WEEKDAY(gps_datetime)                                0.337476
# WEEKDAY(alertDateTime)                               0.433723
# WEEKDAY(jamUpdateDateTime)                           0.337476
# WEEKDAY(jamExpirationDateTime)                       0.305041
#
#                                   MONTH(gps_datetime)  MONTH(alertDateTime)  \
# route                                             NaN             -0.024630
# tripNum                                           NaN              0.002664
# shapeSequence                                     NaN             -0.024738
# shapeLat                                          NaN              0.009365
# shapeLon                                          NaN             -0.022876
# distanceTraveledShape                             NaN             -0.012892
# busCode                                           NaN             -0.034624
# gpsPointId                                        NaN             -0.014965
# gpsLat                                            NaN              0.004695
# gpsLon                                            NaN             -0.022171
# distanceToShapePoint                              NaN              0.000005
# stopPointId                                       NaN             -0.000456
# alertRoadType                                     NaN              0.006579
# alertConfidence                                   NaN             -0.090367
# alertNComments                                    NaN             -0.072206
# alertNImages                                      NaN              0.002810
# alertNThumbsUp                                    NaN             -0.080195
# alertReliability                                  NaN             -0.063085
# alertReportMood                                   NaN              0.035326
# alertReportRating                                 NaN              0.009156
# alertSpeed                                        NaN                   NaN
# alertLatitude                                     NaN              0.009697
# alertLongitude                                    NaN             -0.022582
# alertDistanceToClosestShapePoint                  NaN             -0.006857
# alertIsJamUnifiedAlert                            NaN                   NaN
# alertInScale                                      NaN              0.014232
# jamDelay                                          NaN              0.006876
# jamLength                                         NaN             -0.008934
# jamLevel                                          NaN              0.013162
# jamSeverity                                       NaN             -0.001733
# jamSpeedKM                                        NaN             -0.010738
# jamDistanceToClosestShapePoint                    NaN             -0.011426
# headway                                           NaN             -0.013993
# busBunching                                       NaN              0.004894
# nextBusCode                                       NaN             -0.034319
# DAY(gps_datetime)                                 NaN              0.055003
# DAY(alertDateTime)                                NaN             -0.085465
# DAY(jamUpdateDateTime)                            NaN              0.056340
# DAY(jamExpirationDateTime)                        NaN                   NaN
# YEAR(gps_datetime)                                NaN                   NaN
# YEAR(alertDateTime)                               NaN                   NaN
# YEAR(jamUpdateDateTime)                           NaN                   NaN
# YEAR(jamExpirationDateTime)                       NaN                   NaN
# MONTH(gps_datetime)                               1.0                   NaN
# MONTH(alertDateTime)                              NaN              1.000000
# MONTH(jamUpdateDateTime)                          NaN                   NaN
# MONTH(jamExpirationDateTime)                      NaN                   NaN
# WEEKDAY(gps_datetime)                             NaN             -0.009541
# WEEKDAY(alertDateTime)                            NaN              0.005118
# WEEKDAY(jamUpdateDateTime)                        NaN             -0.007401
# WEEKDAY(jamExpirationDateTime)                    NaN                   NaN
#
#                                   MONTH(jamUpdateDateTime)  \
# route                                                  NaN
# tripNum                                                NaN
# shapeSequence                                          NaN
# shapeLat                                               NaN
# shapeLon                                               NaN
# distanceTraveledShape                                  NaN
# busCode                                                NaN
# gpsPointId                                             NaN
# gpsLat                                                 NaN
# gpsLon                                                 NaN
# distanceToShapePoint                                   NaN
# stopPointId                                            NaN
# alertRoadType                                          NaN
# alertConfidence                                        NaN
# alertNComments                                         NaN
# alertNImages                                           NaN
# alertNThumbsUp                                         NaN
# alertReliability                                       NaN
# alertReportMood                                        NaN
# alertReportRating                                      NaN
# alertSpeed                                             NaN
# alertLatitude                                          NaN
# alertLongitude                                         NaN
# alertDistanceToClosestShapePoint                       NaN
# alertIsJamUnifiedAlert                                 NaN
# alertInScale                                           NaN
# jamDelay                                               NaN
# jamLength                                              NaN
# jamLevel                                               NaN
# jamSeverity                                            NaN
# jamSpeedKM                                             NaN
# jamDistanceToClosestShapePoint                         NaN
# headway                                                NaN
# busBunching                                            NaN
# nextBusCode                                            NaN
# DAY(gps_datetime)                                      NaN
# DAY(alertDateTime)                                     NaN
# DAY(jamUpdateDateTime)                                 NaN
# DAY(jamExpirationDateTime)                             NaN
# YEAR(gps_datetime)                                     NaN
# YEAR(alertDateTime)                                    NaN
# YEAR(jamUpdateDateTime)                                NaN
# YEAR(jamExpirationDateTime)                            NaN
# MONTH(gps_datetime)                                    NaN
# MONTH(alertDateTime)                                   NaN
# MONTH(jamUpdateDateTime)                               1.0
# MONTH(jamExpirationDateTime)                           NaN
# WEEKDAY(gps_datetime)                                  NaN
# WEEKDAY(alertDateTime)                                 NaN
# WEEKDAY(jamUpdateDateTime)                             NaN
# WEEKDAY(jamExpirationDateTime)                         NaN
#
#                                   MONTH(jamExpirationDateTime)  \
# route                                                 0.076042
# tripNum                                               0.195926
# shapeSequence                                         0.029292
# shapeLat                                              0.351802
# shapeLon                                              0.423385
# distanceTraveledShape                                -0.292020
# busCode                                               0.482184
# gpsPointId                                            0.362071
# gpsLat                                                0.300300
# gpsLon                                                0.367270
# distanceToShapePoint                                 -0.157394
# stopPointId                                          -0.032263
# alertRoadType                                        -0.379929
# alertConfidence                                      -0.131487
# alertNComments                                       -0.022935
# alertNImages                                               NaN
# alertNThumbsUp                                       -0.143508
# alertReliability                                     -0.280903
# alertReportMood                                       0.015147
# alertReportRating                                     0.095548
# alertSpeed                                                 NaN
# alertLatitude                                         0.222206
# alertLongitude                                        0.563382
# alertDistanceToClosestShapePoint                     -0.105168
# alertIsJamUnifiedAlert                                0.565487
# alertInScale                                          0.389214
# jamDelay                                                   NaN
# jamLength                                            -0.392547
# jamLevel                                                   NaN
# jamSeverity                                          -0.052354
# jamSpeedKM                                                 NaN
# jamDistanceToClosestShapePoint                        0.052633
# headway                                              -0.062677
# busBunching                                           0.051386
# nextBusCode                                           0.484644
# DAY(gps_datetime)                                     0.519219
# DAY(alertDateTime)                                    0.460613
# DAY(jamUpdateDateTime)                                0.519219
# DAY(jamExpirationDateTime)                           -0.607950
# YEAR(gps_datetime)                                         NaN
# YEAR(alertDateTime)                                        NaN
# YEAR(jamUpdateDateTime)                                    NaN
# YEAR(jamExpirationDateTime)                          -0.985068
# MONTH(gps_datetime)                                        NaN
# MONTH(alertDateTime)                                       NaN
# MONTH(jamUpdateDateTime)                                   NaN
# MONTH(jamExpirationDateTime)                          1.000000
# WEEKDAY(gps_datetime)                                -0.330074
# WEEKDAY(alertDateTime)                               -0.421910
# WEEKDAY(jamUpdateDateTime)                           -0.330074
# WEEKDAY(jamExpirationDateTime)                       -0.300486
#
#                                   WEEKDAY(gps_datetime)  \
# route                                         -0.020758
# tripNum                                        0.018256
# shapeSequence                                 -0.003107
# shapeLat                                      -0.004846
# shapeLon                                      -0.029191
# distanceTraveledShape                          0.002813
# busCode                                       -0.012861
# gpsPointId                                    -0.226742
# gpsLat                                         0.010319
# gpsLon                                        -0.024464
# distanceToShapePoint                          -0.000272
# stopPointId                                   -0.037568
# alertRoadType                                 -0.017941
# alertConfidence                                0.001719
# alertNComments                                -0.003641
# alertNImages                                   0.001847
# alertNThumbsUp                                 0.031343
# alertReliability                               0.040485
# alertReportMood                                0.028734
# alertReportRating                             -0.023456
# alertSpeed                                          NaN
# alertLatitude                                  0.022616
# alertLongitude                                 0.009771
# alertDistanceToClosestShapePoint               0.081033
# alertIsJamUnifiedAlert                        -0.111120
# alertInScale                                  -0.101261
# jamDelay                                      -0.162405
# jamLength                                     -0.197771
# jamLevel                                      -0.117417
# jamSeverity                                   -0.268209
# jamSpeedKM                                    -0.089069
# jamDistanceToClosestShapePoint                 0.088991
# headway                                        0.120181
# busBunching                                   -0.074482
# nextBusCode                                   -0.013077
# DAY(gps_datetime)                             -0.285409
# DAY(alertDateTime)                            -0.231969
# DAY(jamUpdateDateTime)                        -0.291277
# DAY(jamExpirationDateTime)                     0.255497
# YEAR(gps_datetime)                                  NaN
# YEAR(alertDateTime)                                 NaN
# YEAR(jamUpdateDateTime)                             NaN
# YEAR(jamExpirationDateTime)                    0.337476
# MONTH(gps_datetime)                                 NaN
# MONTH(alertDateTime)                          -0.009541
# MONTH(jamUpdateDateTime)                            NaN
# MONTH(jamExpirationDateTime)                  -0.330074
# WEEKDAY(gps_datetime)                          1.000000
# WEEKDAY(alertDateTime)                         0.958904
# WEEKDAY(jamUpdateDateTime)                     0.999889
# WEEKDAY(jamExpirationDateTime)                 0.402603
#
#                                   WEEKDAY(alertDateTime)  \
# route                                           0.021731
# tripNum                                         0.060642
# shapeSequence                                   0.024527
# shapeLat                                        0.020306
# shapeLon                                        0.016719
# distanceTraveledShape                           0.001948
# busCode                                         0.038843
# gpsPointId                                     -0.204290
# gpsLat                                          0.030081
# gpsLon                                          0.008383
# distanceToShapePoint                           -0.009329
# stopPointId                                    -0.033750
# alertRoadType                                  -0.028268
# alertConfidence                                -0.013385
# alertNComments                                 -0.002603
# alertNImages                                    0.001783
# alertNThumbsUp                                  0.012730
# alertReliability                                0.027243
# alertReportMood                                 0.027670
# alertReportRating                              -0.026561
# alertSpeed                                           NaN
# alertLatitude                                   0.021663
# alertLongitude                                  0.017049
# alertDistanceToClosestShapePoint                0.080413
# alertIsJamUnifiedAlert                               NaN
# alertInScale                                    0.018138
# jamDelay                                       -0.175415
# jamLength                                      -0.201285
# jamLevel                                       -0.132879
# jamSeverity                                    -0.295268
# jamSpeedKM                                     -0.081137
# jamDistanceToClosestShapePoint                  0.086939
# headway                                         0.126788
# busBunching                                    -0.093504
# nextBusCode                                     0.038617
# DAY(gps_datetime)                              -0.219209
# DAY(alertDateTime)                             -0.206805
# DAY(jamUpdateDateTime)                         -0.208563
# DAY(jamExpirationDateTime)                      0.252493
# YEAR(gps_datetime)                                   NaN
# YEAR(alertDateTime)                                  NaN
# YEAR(jamUpdateDateTime)                              NaN
# YEAR(jamExpirationDateTime)                     0.433723
# MONTH(gps_datetime)                                  NaN
# MONTH(alertDateTime)                            0.005118
# MONTH(jamUpdateDateTime)                             NaN
# MONTH(jamExpirationDateTime)                   -0.421910
# WEEKDAY(gps_datetime)                           0.958904
# WEEKDAY(alertDateTime)                          1.000000
# WEEKDAY(jamUpdateDateTime)                      0.961733
# WEEKDAY(jamExpirationDateTime)                  0.645310
#
#                                   WEEKDAY(jamUpdateDateTime)  \
# route                                               0.009739
# tripNum                                             0.048622
# shapeSequence                                       0.013837
# shapeLat                                            0.041669
# shapeLon                                           -0.003537
# distanceTraveledShape                              -0.003011
# busCode                                             0.027350
# gpsPointId                                         -0.232211
# gpsLat                                              0.046978
# gpsLon                                             -0.006863
# distanceToShapePoint                               -0.007957
# stopPointId                                        -0.031524
# alertRoadType                                      -0.004764
# alertConfidence                                     0.002026
# alertNComments                                      0.008962
# alertNImages                                        0.002980
# alertNThumbsUp                                      0.038786
# alertReliability                                    0.050936
# alertReportMood                                     0.034880
# alertReportRating                                  -0.026350
# alertSpeed                                               NaN
# alertLatitude                                       0.041403
# alertLongitude                                     -0.007358
# alertDistanceToClosestShapePoint                    0.103968
# alertIsJamUnifiedAlert                             -0.268937
# alertInScale                                       -0.216506
# jamDelay                                           -0.162403
# jamLength                                          -0.197808
# jamLevel                                           -0.117402
# jamSeverity                                        -0.268250
# jamSpeedKM                                         -0.089098
# jamDistanceToClosestShapePoint                      0.089004
# headway                                             0.124283
# busBunching                                        -0.088612
# nextBusCode                                         0.027072
# DAY(gps_datetime)                                  -0.291236
# DAY(alertDateTime)                                 -0.219728
# DAY(jamUpdateDateTime)                             -0.291240
# DAY(jamExpirationDateTime)                          0.255497
# YEAR(gps_datetime)                                       NaN
# YEAR(alertDateTime)                                      NaN
# YEAR(jamUpdateDateTime)                                  NaN
# YEAR(jamExpirationDateTime)                         0.337476
# MONTH(gps_datetime)                                      NaN
# MONTH(alertDateTime)                               -0.007401
# MONTH(jamUpdateDateTime)                                 NaN
# MONTH(jamExpirationDateTime)                       -0.330074
# WEEKDAY(gps_datetime)                               0.999889
# WEEKDAY(alertDateTime)                              0.961733
# WEEKDAY(jamUpdateDateTime)                          1.000000
# WEEKDAY(jamExpirationDateTime)                      0.402603
#
#                                   WEEKDAY(jamExpirationDateTime)
# route                                                   0.117887
# tripNum                                                 0.274038
# shapeSequence                                           0.094297
# shapeLat                                               -0.099169
# shapeLon                                               -0.215701
# distanceTraveledShape                                   0.150361
# busCode                                                -0.162686
# gpsPointId                                             -0.155089
# gpsLat                                                  0.029730
# gpsLon                                                 -0.149748
# distanceToShapePoint                                    0.173766
# stopPointId                                            -0.265358
# alertRoadType                                           0.154514
# alertConfidence                                        -0.146818
# alertNComments                                          0.143954
# alertNImages                                                 NaN
# alertNThumbsUp                                         -0.193518
# alertReliability                                       -0.129708
# alertReportMood                                         0.010301
# alertReportRating                                      -0.275033
# alertSpeed                                                   NaN
# alertLatitude                                          -0.156473
# alertLongitude                                         -0.358022
# alertDistanceToClosestShapePoint                        0.283948
# alertIsJamUnifiedAlert                                 -0.072148
# alertInScale                                           -0.014868
# jamDelay                                                     NaN
# jamLength                                               0.324037
# jamLevel                                                     NaN
# jamSeverity                                             0.281948
# jamSpeedKM                                                   NaN
# jamDistanceToClosestShapePoint                         -0.045884
# headway                                                 0.115814
# busBunching                                            -0.123571
# nextBusCode                                            -0.155646
# DAY(gps_datetime)                                      -0.079171
# DAY(alertDateTime)                                     -0.425092
# DAY(jamUpdateDateTime)                                 -0.079171
# DAY(jamExpirationDateTime)                              0.618809
# YEAR(gps_datetime)                                           NaN
# YEAR(alertDateTime)                                          NaN
# YEAR(jamUpdateDateTime)                                      NaN
# YEAR(jamExpirationDateTime)                             0.305041
# MONTH(gps_datetime)                                          NaN
# MONTH(alertDateTime)                                         NaN
# MONTH(jamUpdateDateTime)                                     NaN
# MONTH(jamExpirationDateTime)                           -0.300486
# WEEKDAY(gps_datetime)                                   0.402603
# WEEKDAY(alertDateTime)                                  0.645310
# WEEKDAY(jamUpdateDateTime)                              0.402603
# WEEKDAY(jamExpirationDateTime)                          1.000000
#
# [51 rows x 51 columns]

# %%
plot_corr(kendall_corr)

# %% [markdown]
# ### Brief Discussion about Pearson, Spearman and Kendall coeficients
#
# * They don't consider categorical variables: alertType, alertSubType, jamBlockType, shapeID, routeFrequency, problem.
#
# * NaN: For constant variables, it's impossible to measure correlation because there is no variation.
