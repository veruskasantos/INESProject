# %% [markdown]
# ## Data integration script

# %% [markdown]
# The aim of this task is to integrate in the same file the following data:
# - GPS;
# - Weather;
# - Waze;
# - GTFS
#
# Example of final file attributes (to use in ML algorithms):
#
#
# The task has the following steps:
# 1. Clean the data (removing missing/wrong data);
# 2. Label shape file with route type (low/high frequency)
# 3. Update and run BULMA (matching of GPS and GTFS);
# 4. Update and run BUSTE (interpolate stops timestamp)
# 5. Label each GPS with headway value and BB (headway, BB, id_bus_bb)
# 6. Label with precipitation (precipitation)

# %%
import utm
import os
import pandas as pd
from datetime import datetime
from numpy import median
import math
import pandas

# %% [markdown]
# ### Data example
#
# #### GPS
# - bus_code
# - timestamp
# - route
# - latitude
# - longitude
#
# #### Weather
#
# #### Waze
#
# #### GTFS

# %% [markdown]
# Pre-processing GPS data of Recife to separate files per day and to convert coordinates.

# %%
def convertCoordinates(x, y):
    if (x == '-' or x == '0' or y == '-' or y == '0'):
        return ['-', '-']
    
    return utm.to_latlon(long(x), long(y), 25, 'M')
    
def separateGPSFilePerMonth(file_path):
    DELIMITER = ','
    october_file = open(file_path + 'GPS_data_october.csv', 'w')
    november_file = open(file_path + 'GPS_data_november.csv', 'w')
    december_file = open(file_path + 'GPS_data_december.csv', 'w')
    columns_name = "Unidad" + DELIMITER +  "Instante" + DELIMITER + "Estado" + DELIMITER + "Comunica" + DELIMITER + "CoordX" + DELIMITER + "CoordY" + DELIMITER + "Linea" + DELIMITER + "Ruta" + DELIMITER + "Posicion" + DELIMITER + "Viaje" + DELIMITER + "Velocidad"
    october_file.write(columns_name + '\n')
    november_file.write(columns_name + '\n')
    december_file.write(columns_name + '\n')
    
    october = '2018-10'
    november = '2018-11'
    december = '2018-12'
    
    file_name = file_path + "GPS_data.csv"
    with open(file_name, 'r') as gps_data:
        next(gps_data)
        for line in gps_data:
            line_splitted = line.split(',')
            date = line_splitted[1]
            lat = line_splitted[4]
            lon = line_splitted[5]
            new_coordinates = convertCoordinates(lat, lon)
            
            new_line = line_splitted[0] + DELIMITER + line_splitted[1] + DELIMITER + line_splitted[2] + DELIMITER + line_splitted[3] + DELIMITER + str(new_coordinates[0]) + DELIMITER + str(new_coordinates[1]) + DELIMITER + line_splitted[6] + DELIMITER + line_splitted[7] + DELIMITER + line_splitted[8] + DELIMITER + line_splitted[9] + DELIMITER + line_splitted[10]
            
            if (october in date):
                october_file.write(new_line)
            elif (november in date):
                november_file.write(new_line)
            elif (december in date):
                december_file.write(new_line)

def separateGPSFilePerDay(file_path):
    DELIMITER = ','
    columns_name = "Unidad" + DELIMITER +  "Instante" + DELIMITER + "Estado" + DELIMITER + "Comunica" + DELIMITER + "CoordX" + DELIMITER + "CoordY" + DELIMITER + "Linea" + DELIMITER + "Ruta" + DELIMITER + "Posicion" + DELIMITER + "Viaje" + DELIMITER + "Velocidad"
    file_name = file_path + "GPS_data_october.csv"
    date_lines_dict = {}
    with open(file_name, 'r') as gps_data:
        next(gps_data)
        for line in gps_data:
            line_splitted = line.split(',')
            date_time = line_splitted[1]
            date = date_time.split(' ')[0]
            
            if (date not in date_lines_dict):
                date_lines_dict[date] = []
            
            date_lines_dict[date].append(line)
            
    
    for key in date_lines_dict:
        new_file = open(file_path + 'GPS_data_' + key + '.csv', 'w')
        new_file.write(columns_name + '\n')
        
        for data_per_day in date_lines_dict[key]:
            new_file.write(data_per_day)
            
        new_file.close()
            
file_path = os.getcwd() + "/../data/input/Recife/GPS/"

separateGPSFilePerMonth(file_path)

separateGPSFilePerDay(file_path)

# %% [markdown]
# ### 1. Clean the data
# Removing missing/wrong data
#
# #### 1.1 Waze

# %%
# Waze
# Removing lines from different city

def removeDifferentCity(dir_name, city_label):
    
    for file_name in os.listdir(dir_name):
        
        if file_name.endswith(".csv"): # to get just files
            file_path = dir_name + file_name

            new_file = open(dir_name + 'clean/' + file_name, 'w')

            with open(file_path, 'r') as waze_data:
                new_file.write(next(waze_data)) # write the header
                
                for line in waze_data:
                    line_splitted = line.split(',')
                    city = line_splitted[1]

                    if (city_label in city):
                        new_file.write(line) # to add just lines of the city

                new_file.close()
            
# Alert: create the folder 'clean', set the path and the city name            
dir_path = os.getcwd() + "/../data/input/Recife/Waze/"
city = 'Recife'
removeDifferentCity(dir_path, city)

# %% [markdown]
# #### 1.2 GPS
#
# Removing Recife data without *linea* (route) or *CoordX* or *CoordY*

# %%
# GPS - Recife
# Removing lines without linea or CoordX or CoordY

def cleanRecifeGPS(dir_path):
    for file_name in os.listdir(dir_path):
        
        if file_name.endswith(".csv"): # to get just files
            file_path = dir_path + file_name
            
            new_file = open(dir_path + 'clean/' + file_name, 'w')

            with open(file_path, 'r') as gps_data:
                new_file.write(next(gps_data)) # write the header
                
                for line in gps_data:
                    line_splitted = line.split(',')
                    route = line_splitted[6]
                    lat = line_splitted[4]
                    lon = line_splitted[5]

                    if (route != '' and lat != '-' and lat != '' and lon != '-' and lon != ''):
                        new_file.write(line) # to add just lines not empty

                new_file.close()
                
# Alert: create the folder 'csv' 
dir_path = os.getcwd() + "/../data/input/Recife/GPS/"
cleanRecifeGPS(dir_path)

# %%
# GPS - Curitiba
# Converting json file to csv file

# Alert: first, replace }{ by },{ 
# sed -i ':a;N;$!ba;s/}/},/g' *.json

def convertJSON2CSV(dir_path):
    DELIMITER = ','
    columns_name = "bus_code" + DELIMITER + "lat" + DELIMITER + "lon" + DELIMITER + "timestamp" + DELIMITER + "route"
    
    for file_name in os.listdir(dir_path):
        
        if file_name.endswith(".json"): # to get just files
            file_path = dir_path + file_name
            
            new_file = open(dir_path + 'csv/' + file_name.split('.')[0] + '.csv', 'w')

            new_file.write(columns_name + "\n")
            
            with open(file_path, 'r') as gps_data:
                next(gps_data) # skip empty line 
                for line in gps_data:
                    line_splitted = line.split(',')
                    bus_code = line_splitted[0].split('":')[1]
                    lat = line_splitted[1].split('":')[1]
                    lon = line_splitted[2].split('":')[1]
                    timestamp = line_splitted[3].split('":')[1]
                    route = line_splitted[4].split('":')[1][:-1]
                    
                    new_line = bus_code + DELIMITER + lat + DELIMITER + lon + DELIMITER + timestamp + DELIMITER + route
                    
                    new_file.write(new_line + "\n")
            
dir_path = os.getcwd() + "/../data/input/Curitiba/GPS/"
convertJSON2CSV(dir_path)

# %% [markdown]
# ### 2. Label shape file with route type
#
# Label shape file with route type: high frequency or low frequency based on *headway median of the city (h_median)*.
#
# - **High frequency:** headway mean of the route <= h_median
# - **Low frequency:** headway mean of the route > h_median

# %% [markdown]
# <img src="trips_file_example.png">
#
# The *stop_times* file has the information:
# - Buses: all the schedules of the bus are grouped, e.g. the schedules of the first bus are the firsts lines (from 5:00 to 23:00)
# - Headway: the diference of the *arrival_time* of the bus and the follow.

# %% [markdown]
# **Challenge: how to separate different buses to compare headways?**

# %%
# Alert: Set the path with the city name            
dir_path = os.getcwd() + "/../data/input/Curitiba/GTFS/"
trips_file = 'trips.txt'
stop_times_file = 'stop_times.txt'

# Read trips.txt to get the route of the trips
def getRouteTripsMap():
    route_trips_map = {}
    
    with open(dir_path + trips_file, 'r') as trips_data:
        next(trips_data) # skip header
        
        for line in trips_data:
            splitted_line = line.split(',')
            route = splitted_line[0]
            trip_id = splitted_line[2]
            
            if (route not in route_trips_map):
                route_trips_map[route] = []
            
            route_trips_map[route].append(trip_id)
    
#     print(route_trips_map)
    
    return route_trips_map
    

# Read stop_times.txt to get the stop_times of each trip
def getTripsStopsTimesMap(route_trips_map):
    route_stops_times = {}
    
    with open(dir_path + stop_times_file, 'r') as stops_times_data:
        next(stops_times_data) # skip header
        
        for line in stops_times_data:
            splitted_line = line.split(',')
            trip_id = splitted_line[0]
            stop_id = splitted_line[3]
            arrival_time = splitted_line[1]
            
            # get the route of the trip 
            for key, trips in route_trips_map.items():
                if trip_id in trips:
                    route = key

            if (route not in route_stops_times):
                route_stops_times[route] = {}
            
            if (stop_id not in route_stops_times[route]):
                route_stops_times[route][stop_id] = []
            
            route_stops_times[route][stop_id].append(arrival_time)
                    
#     print(route_stops_times['34'])
    return route_stops_times


# Calculate the headway(difference between two timestamps) in seconds
def getHeadway(time1, time2):
    t1 = datetime.strptime(time1, "%H:%M:%S")
    t2 = datetime.strptime(time2, "%H:%M:%S")
    difference = t2 - t1
    
    return difference.seconds

# %%
route_trips_map = getRouteTripsMap()
route_stops_times = getTripsStopsTimesMap(route_trips_map)

# %%
# Calculate headway median of each route;
# headway median of the city.
def calculateRoutesHeadways(route_stops_times):
    route_headway_median_map = {}
    sum_headways_city = []
    
    for route, stopstimes in route_stops_times.items():
        
        sum_headways_route = []
        
        for stops, times in stopstimes.items():
            last_time = 0
            
            # Order times before to iterate
            ordered_times = sorted(times, key=lambda d: map(int, d.split(':')))
            for time in ordered_times:
                
                # skip the first timestamp or wrong data
                if (last_time != 0 and not time.startswith('24:') and not last_time.startswith('24:')): 
                    # mean doesn't work because some routes run in specific times
                    headway = getHeadway(last_time, time)
                    
                    sum_headways_route.append(headway)
                    
                last_time = time
                
        # calculate the median headway of the route
        if (len(sum_headways_route) > 0):
            headway_route = median(sum_headways_route)
            route_headway_median_map[route] = headway_route
            
            sum_headways_city.append(headway_route)
        
    median_headway_city = median(sum_headways_city)
    return (median_headway_city, route_headway_median_map)
    
median_headway_city, route_headway_median_map = calculateRoutesHeadways(route_stops_times)

# %%
#TODO run to CG and Recife

# Update routes.txt file with frequency (high or low) label
# based on its median headway and the median headway city
def updateRoutesFile(file_path, median_headway_city, route_headway_median_map):
    
    new_routes_file = open(file_path + 'routes_label.txt', 'w')
    DELIMITER = ','
    
    with open(file_path + 'routes.txt', 'r') as routes_data:
        columns_name = next(routes_data).split(DELIMITER)
        
        new_routes_file.write(columns_name[0] + DELIMITER + columns_name[1] + DELIMITER + columns_name[2]
                               + DELIMITER + columns_name[3] + DELIMITER + columns_name[4] + DELIMITER 
                              + columns_name[5] + DELIMITER + columns_name[6] + DELIMITER + columns_name[7] 
                               + DELIMITER + 'frequency' + DELIMITER + columns_name[8]) # write header 
        
        for line in routes_data:
            line_splitted = line.split(DELIMITER)
            route = str(line_splitted[0])
            
            # When there was no data to calculate headway or when route headway > city headway
            label = 'low_frequency'
            headway = '-'
            
            if (route in route_headway_median_map):
                headway = route_headway_median_map[route]
                if (headway <= median_headway_city):
                    label = 'high_frequency'
            
            print('Route: ' + route, 'headway_city: ' + str(median_headway_city), 
                  'headway_route: ' + str(headway), 'label: ' + label)
            
            new_line = line_splitted[0] + DELIMITER + line_splitted[1] + DELIMITER + line_splitted[2] + DELIMITER + line_splitted[3] + DELIMITER + line_splitted[4] + DELIMITER + line_splitted[5] + DELIMITER + line_splitted[6] + DELIMITER + line_splitted[7] + DELIMITER + label + DELIMITER + line_splitted[8]
            new_routes_file.write(new_line)
            
    new_routes_file.close()

# Alert: change the city name
file_path = os.getcwd() + "/../data/input/Curitiba/GTFS/"
updateRoutesFile(file_path, median_headway_city, route_headway_median_map)
# Out:
# ('Route: 1', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 6', 'headway_city: 1413.0', 'headway_route: 1823.0', 'label: low_frequency')
# ('Route: 7', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 12', 'headway_city: 1413.0', 'headway_route: 2040.0', 'label: low_frequency')
# ('Route: 16', 'headway_city: 1413.0', 'headway_route: 1612.0', 'label: low_frequency')
# ('Route: 17', 'headway_city: 1413.0', 'headway_route: 639.0', 'label: high_frequency')
# ('Route: 20', 'headway_city: 1413.0', 'headway_route: 1680.0', 'label: low_frequency')
# ('Route: 21', 'headway_city: 1413.0', 'headway_route: 1080.0', 'label: high_frequency')
# ('Route: 22', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 25', 'headway_city: 1413.0', 'headway_route: 1345.0', 'label: high_frequency')
# ('Route: 27', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 29', 'headway_city: 1413.0', 'headway_route: 1020.0', 'label: high_frequency')
# ('Route: 30', 'headway_city: 1413.0', 'headway_route: 1320.0', 'label: high_frequency')
# ('Route: 31', 'headway_city: 1413.0', 'headway_route: 1320.0', 'label: high_frequency')
# ('Route: 32', 'headway_city: 1413.0', 'headway_route: 1184.0', 'label: high_frequency')
# ('Route: 33', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 34', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 35', 'headway_city: 1413.0', 'headway_route: 1260.0', 'label: high_frequency')
# ('Route: 39', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 40', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 41', 'headway_city: 1413.0', 'headway_route: 2160.0', 'label: low_frequency')
# ('Route: 42', 'headway_city: 1413.0', 'headway_route: 960.0', 'label: high_frequency')
# ('Route: 43', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 44', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 45', 'headway_city: 1413.0', 'headway_route: 1140.0', 'label: high_frequency')
# ('Route: 46', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 48', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 52', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 54', 'headway_city: 1413.0', 'headway_route: 1812.5', 'label: low_frequency')
# ('Route: 55', 'headway_city: 1413.0', 'headway_route: 1413.0', 'label: high_frequency')
# ('Route: 56', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 57', 'headway_city: 1413.0', 'headway_route: 1560.0', 'label: low_frequency')
# ('Route: 60', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 62', 'headway_city: 1413.0', 'headway_route: 3278.0', 'label: low_frequency')
# ('Route: 63', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 64', 'headway_city: 1413.0', 'headway_route: 840.0', 'label: high_frequency')
# ('Route: 65', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 66', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 67', 'headway_city: 1413.0', 'headway_route: 8280.0', 'label: low_frequency')
# ('Route: 68', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 70', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 71', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 72', 'headway_city: 1413.0', 'headway_route: 420.0', 'label: high_frequency')
# ('Route: 74', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 75', 'headway_city: 1413.0', 'headway_route: 1920.0', 'label: low_frequency')
# ('Route: 77', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 78', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 79', 'headway_city: 1413.0', 'headway_route: 1620.0', 'label: low_frequency')
# ('Route: 80', 'headway_city: 1413.0', 'headway_route: 1768.0', 'label: low_frequency')
# ('Route: 82', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 83', 'headway_city: 1413.0', 'headway_route: 1546.0', 'label: low_frequency')
# ('Route: 84', 'headway_city: 1413.0', 'headway_route: 536.0', 'label: high_frequency')
# ('Route: 88', 'headway_city: 1413.0', 'headway_route: 1620.0', 'label: low_frequency')
# ('Route: 89', 'headway_city: 1413.0', 'headway_route: 4713.5', 'label: low_frequency')
# ('Route: 90', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 91', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 94', 'headway_city: 1413.0', 'headway_route: 3450.0', 'label: low_frequency')
# ('Route: 95', 'headway_city: 1413.0', 'headway_route: 1818.5', 'label: low_frequency')
# ('Route: 98', 'headway_city: 1413.0', 'headway_route: 3000.0', 'label: low_frequency')
# ('Route: 99', 'headway_city: 1413.0', 'headway_route: 1750.0', 'label: low_frequency')
# ('Route: 100', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 102', 'headway_city: 1413.0', 'headway_route: 1320.0', 'label: high_frequency')
# ('Route: 105', 'headway_city: 1413.0', 'headway_route: 2242.0', 'label: low_frequency')
# ('Route: 106', 'headway_city: 1413.0', 'headway_route: 1560.0', 'label: low_frequency')
# ('Route: 110', 'headway_city: 1413.0', 'headway_route: 1920.0', 'label: low_frequency')
# ('Route: 112', 'headway_city: 1413.0', 'headway_route: 954.0', 'label: high_frequency')
# ('Route: 113', 'headway_city: 1413.0', 'headway_route: 1845.0', 'label: low_frequency')
# ('Route: 114', 'headway_city: 1413.0', 'headway_route: 960.0', 'label: high_frequency')
# ('Route: 115', 'headway_city: 1413.0', 'headway_route: 1320.0', 'label: high_frequency')
# ('Route: 116', 'headway_city: 1413.0', 'headway_route: 360.0', 'label: high_frequency')
# ('Route: 122', 'headway_city: 1413.0', 'headway_route: 7200.0', 'label: low_frequency')
# ('Route: 123', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 125', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 126', 'headway_city: 1413.0', 'headway_route: 1232.0', 'label: high_frequency')
# ('Route: 127', 'headway_city: 1413.0', 'headway_route: 1267.0', 'label: high_frequency')
# ('Route: 128', 'headway_city: 1413.0', 'headway_route: 1374.0', 'label: high_frequency')
# ('Route: 132', 'headway_city: 1413.0', 'headway_route: 1920.0', 'label: low_frequency')
# ('Route: 134', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 137', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 139', 'headway_city: 1413.0', 'headway_route: 1080.0', 'label: high_frequency')
# ('Route: 141', 'headway_city: 1413.0', 'headway_route: 1145.0', 'label: high_frequency')
# ('Route: 142', 'headway_city: 1413.0', 'headway_route: 1466.0', 'label: low_frequency')
# ('Route: 143', 'headway_city: 1413.0', 'headway_route: 1080.0', 'label: high_frequency')
# ('Route: 144', 'headway_city: 1413.0', 'headway_route: 1377.0', 'label: high_frequency')
# ('Route: 145', 'headway_city: 1413.0', 'headway_route: 2700.0', 'label: low_frequency')
# ('Route: 146', 'headway_city: 1413.0', 'headway_route: 1366.0', 'label: high_frequency')
# ('Route: 147', 'headway_city: 1413.0', 'headway_route: 2040.0', 'label: low_frequency')
# ('Route: 148', 'headway_city: 1413.0', 'headway_route: 1056.5', 'label: high_frequency')
# ('Route: 150', 'headway_city: 1413.0', 'headway_route: 840.0', 'label: high_frequency')
# ('Route: 151', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 153', 'headway_city: 1413.0', 'headway_route: 1128.0', 'label: high_frequency')
# ('Route: 156', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 162', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 164', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 170', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 171', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 173', 'headway_city: 1413.0', 'headway_route: 660.0', 'label: high_frequency')
# ('Route: 174', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 175', 'headway_city: 1413.0', 'headway_route: 1560.0', 'label: low_frequency')
# ('Route: 176', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 177', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 178', 'headway_city: 1413.0', 'headway_route: 1565.0', 'label: low_frequency')
# ('Route: 179', 'headway_city: 1413.0', 'headway_route: 431.0', 'label: high_frequency')
# ('Route: 180', 'headway_city: 1413.0', 'headway_route: 840.0', 'label: high_frequency')
# ('Route: 181', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 182', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 183', 'headway_city: 1413.0', 'headway_route: 2713.0', 'label: low_frequency')
# ('Route: 185', 'headway_city: 1413.0', 'headway_route: 945.0', 'label: high_frequency')
# ('Route: 186', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 187', 'headway_city: 1413.0', 'headway_route: 1260.0', 'label: high_frequency')
# ('Route: 188', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 189', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 190', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 191', 'headway_city: 1413.0', 'headway_route: 1276.0', 'label: high_frequency')
# ('Route: 192', 'headway_city: 1413.0', 'headway_route: 1320.0', 'label: high_frequency')
# ('Route: 193', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 195', 'headway_city: 1413.0', 'headway_route: 1380.0', 'label: high_frequency')
# ('Route: 196', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 197', 'headway_city: 1413.0', 'headway_route: 1380.0', 'label: high_frequency')
# ('Route: 198', 'headway_city: 1413.0', 'headway_route: 710.5', 'label: high_frequency')
# ('Route: 199', 'headway_city: 1413.0', 'headway_route: 1256.5', 'label: high_frequency')
# ('Route: 201', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 202', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 203', 'headway_city: 1413.0', 'headway_route: 660.0', 'label: high_frequency')
# ('Route: 204', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 206', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 208', 'headway_city: 1413.0', 'headway_route: 1314.0', 'label: high_frequency')
# ('Route: 210', 'headway_city: 1413.0', 'headway_route: 1245.0', 'label: high_frequency')
# ('Route: 211', 'headway_city: 1413.0', 'headway_route: 3600.0', 'label: low_frequency')
# ('Route: 212', 'headway_city: 1413.0', 'headway_route: 2001.0', 'label: low_frequency')
# ('Route: 214', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 215', 'headway_city: 1413.0', 'headway_route: 1920.0', 'label: low_frequency')
# ('Route: 216', 'headway_city: 1413.0', 'headway_route: 1080.0', 'label: high_frequency')
# ('Route: 217', 'headway_city: 1413.0', 'headway_route: 1307.0', 'label: high_frequency')
# ('Route: 218', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 220', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 221', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 222', 'headway_city: 1413.0', 'headway_route: 1651.0', 'label: low_frequency')
# ('Route: 223', 'headway_city: 1413.0', 'headway_route: 28976.0', 'label: low_frequency')
# ('Route: 224', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 250', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 251', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 252', 'headway_city: 1413.0', 'headway_route: 1147.5', 'label: high_frequency')
# ('Route: 253', 'headway_city: 1413.0', 'headway_route: 4833.0', 'label: low_frequency')
# ('Route: 254', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 255', 'headway_city: 1413.0', 'headway_route: 670.5', 'label: high_frequency')
# ('Route: 257', 'headway_city: 1413.0', 'headway_route: 3600.0', 'label: low_frequency')
# ('Route: 258', 'headway_city: 1413.0', 'headway_route: 2340.0', 'label: low_frequency')
# ('Route: 270', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 271', 'headway_city: 1413.0', 'headway_route: 1237.0', 'label: high_frequency')
# ('Route: 272', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 274', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 275', 'headway_city: 1413.0', 'headway_route: 1010.0', 'label: high_frequency')
# ('Route: 276', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 277', 'headway_city: 1413.0', 'headway_route: 2160.0', 'label: low_frequency')
# ('Route: 278', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 279', 'headway_city: 1413.0', 'headway_route: 960.0', 'label: high_frequency')
# ('Route: 280', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 281', 'headway_city: 1413.0', 'headway_route: 2056.0', 'label: low_frequency')
# ('Route: 282', 'headway_city: 1413.0', 'headway_route: 6505.0', 'label: low_frequency')
# ('Route: 283', 'headway_city: 1413.0', 'headway_route: 1560.0', 'label: low_frequency')
# ('Route: 284', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 285', 'headway_city: 1413.0', 'headway_route: 1260.0', 'label: high_frequency')
# ('Route: 286', 'headway_city: 1413.0', 'headway_route: 1620.0', 'label: low_frequency')
# ('Route: 287', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 288', 'headway_city: 1413.0', 'headway_route: 2520.0', 'label: low_frequency')
# ('Route: 289', 'headway_city: 1413.0', 'headway_route: 1955.0', 'label: low_frequency')
# ('Route: 290', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 294', 'headway_city: 1413.0', 'headway_route: 3112.0', 'label: low_frequency')
# ('Route: 296', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 297', 'headway_city: 1413.0', 'headway_route: 1179.0', 'label: high_frequency')
# ('Route: 298', 'headway_city: 1413.0', 'headway_route: 480.0', 'label: high_frequency')
# ('Route: 299', 'headway_city: 1413.0', 'headway_route: 840.0', 'label: high_frequency')
# ('Route: 301', 'headway_city: 1413.0', 'headway_route: 360.0', 'label: high_frequency')
# ('Route: 302', 'headway_city: 1413.0', 'headway_route: 1297.5', 'label: high_frequency')
# ('Route: 304', 'headway_city: 1413.0', 'headway_route: 583.0', 'label: high_frequency')
# ('Route: 305', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 306', 'headway_city: 1413.0', 'headway_route: 3600.0', 'label: low_frequency')
# ('Route: 307', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 309', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 310', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 312', 'headway_city: 1413.0', 'headway_route: 2067.0', 'label: low_frequency')
# ('Route: 314', 'headway_city: 1413.0', 'headway_route: 1860.0', 'label: low_frequency')
# ('Route: 315', 'headway_city: 1413.0', 'headway_route: 2743.0', 'label: low_frequency')
# ('Route: 316', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 317', 'headway_city: 1413.0', 'headway_route: 2395.0', 'label: low_frequency')
# ('Route: 318', 'headway_city: 1413.0', 'headway_route: 1747.0', 'label: low_frequency')
# ('Route: 319', 'headway_city: 1413.0', 'headway_route: 2464.0', 'label: low_frequency')
# ('Route: 320', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 321', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 322', 'headway_city: 1413.0', 'headway_route: 1500.0', 'label: low_frequency')
# ('Route: 323', 'headway_city: 1413.0', 'headway_route: 3600.0', 'label: low_frequency')
# ('Route: 325', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 326', 'headway_city: 1413.0', 'headway_route: 2105.5', 'label: low_frequency')
# ('Route: 327', 'headway_city: 1413.0', 'headway_route: 1707.0', 'label: low_frequency')
# ('Route: 328', 'headway_city: 1413.0', 'headway_route: 1200.0', 'label: high_frequency')
# ('Route: 329', 'headway_city: 1413.0', 'headway_route: 1596.0', 'label: low_frequency')
# ('Route: 331', 'headway_city: 1413.0', 'headway_route: 16496.5', 'label: low_frequency')
# ('Route: 333', 'headway_city: 1413.0', 'headway_route: 521.0', 'label: high_frequency')
# ('Route: 334', 'headway_city: 1413.0', 'headway_route: 6600.0', 'label: low_frequency')
# ('Route: 336', 'headway_city: 1413.0', 'headway_route: 980.0', 'label: high_frequency')
# ('Route: 337', 'headway_city: 1413.0', 'headway_route: 360.0', 'label: high_frequency')
# ('Route: 338', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 339', 'headway_city: 1413.0', 'headway_route: 900.0', 'label: high_frequency')
# ('Route: 340', 'headway_city: 1413.0', 'headway_route: 3960.0', 'label: low_frequency')
# ('Route: 342', 'headway_city: 1413.0', 'headway_route: 1170.0', 'label: high_frequency')
# ('Route: 343', 'headway_city: 1413.0', 'headway_route: 660.0', 'label: high_frequency')
# ('Route: 344', 'headway_city: 1413.0', 'headway_route: 660.0', 'label: high_frequency')
# ('Route: 345', 'headway_city: 1413.0', 'headway_route: 5280.0', 'label: low_frequency')
# ('Route: 346', 'headway_city: 1413.0', 'headway_route: 1068.0', 'label: high_frequency')
# ('Route: 347', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 348', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 349', 'headway_city: 1413.0', 'headway_route: 2100.0', 'label: low_frequency')
# ('Route: 350', 'headway_city: 1413.0', 'headway_route: 7200.0', 'label: low_frequency')
# ('Route: 351', 'headway_city: 1413.0', 'headway_route: 4425.0', 'label: low_frequency')
# ('Route: 352', 'headway_city: 1413.0', 'headway_route: 1800.0', 'label: low_frequency')
# ('Route: 353', 'headway_city: 1413.0', 'headway_route: 2509.0', 'label: low_frequency')
# ('Route: 354', 'headway_city: 1413.0', 'headway_route: 660.0', 'label: high_frequency')
# ('Route: 367', 'headway_city: 1413.0', 'headway_route: 600.0', 'label: high_frequency')
# ('Route: 378', 'headway_city: 1413.0', 'headway_route: 1752.0', 'label: low_frequency')
# ('Route: 381', 'headway_city: 1413.0', 'headway_route: 1440.0', 'label: low_frequency')
# ('Route: 383', 'headway_city: 1413.0', 'headway_route: 1573.5', 'label: low_frequency')
# ('Route: 388', 'headway_city: 1413.0', 'headway_route: 1094.0', 'label: high_frequency')
# ('Route: 389', 'headway_city: 1413.0', 'headway_route: 1920.0', 'label: low_frequency')
# ('Route: 391', 'headway_city: 1413.0', 'headway_route: 1463.0', 'label: low_frequency')
# ('Route: 392', 'headway_city: 1413.0', 'headway_route: 1160.0', 'label: high_frequency')
# ('Route: 393', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 400', 'headway_city: 1413.0', 'headway_route: 1194.0', 'label: high_frequency')
# ('Route: 528', 'headway_city: 1413.0', 'headway_route: 3052.0', 'label: low_frequency')
# ('Route: 539', 'headway_city: 1413.0', 'headway_route: 1542.0', 'label: low_frequency')
# ('Route: 568', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 569', 'headway_city: 1413.0', 'headway_route: 1195.0', 'label: high_frequency')
# ('Route: 620', 'headway_city: 1413.0', 'headway_route: 3417.0', 'label: low_frequency')
# ('Route: 738', 'headway_city: 1413.0', 'headway_route: -', 'label: low_frequency')
# ('Route: 745', 'headway_city: 1413.0', 'headway_route: 780.0', 'label: high_frequency')
# ('Route: 747', 'headway_city: 1413.0', 'headway_route: 2020.5', 'label: low_frequency')
# ('Route: 755', 'headway_city: 1413.0', 'headway_route: 19590.0', 'label: low_frequency')
# ('Route: 764', 'headway_city: 1413.0', 'headway_route: 2340.0', 'label: low_frequency')
# ('Route: 765', 'headway_city: 1413.0', 'headway_route: 960.0', 'label: high_frequency')
# ('Route: 775', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 778', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 781', 'headway_city: 1413.0', 'headway_route: 763.0', 'label: high_frequency')
# ('Route: 783', 'headway_city: 1413.0', 'headway_route: 960.0', 'label: high_frequency')
# ('Route: 789', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 791', 'headway_city: 1413.0', 'headway_route: 1119.5', 'label: high_frequency')
# ('Route: 796', 'headway_city: 1413.0', 'headway_route: 1776.5', 'label: low_frequency')
# ('Route: 809', 'headway_city: 1413.0', 'headway_route: 600.0', 'label: high_frequency')
# ('Route: 810', 'headway_city: 1413.0', 'headway_route: 2700.0', 'label: low_frequency')
# ('Route: 817', 'headway_city: 1413.0', 'headway_route: 3840.0', 'label: low_frequency')
# ('Route: 818', 'headway_city: 1413.0', 'headway_route: 720.0', 'label: high_frequency')
# ('Route: 823', 'headway_city: 1413.0', 'headway_route: 1210.0', 'label: high_frequency')
# ('Route: 827', 'headway_city: 1413.0', 'headway_route: 2400.0', 'label: low_frequency')
# ('Route: 839', 'headway_city: 1413.0', 'headway_route: 2504.5', 'label: low_frequency')

# %% [markdown]
# Each stop time belongs to one trip, i.e. the total os trips is the total os time stamps there.

# %% [markdown]
# **Observation:**
#
# - In general, the scheduled headway of Curitiba is 1413 seconds (23 minutes).
# - In general, the scheduled headway of Campina Grande is 1413 seconds (23 minutes).
# - In general, the scheduled headway of Recife is 1413 seconds (23 minutes).
