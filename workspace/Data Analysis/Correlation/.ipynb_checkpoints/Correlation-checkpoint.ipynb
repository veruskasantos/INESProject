# %% [markdown]
# # Correlation Script

# %% [markdown]
# ### TODO: RUN FOR EVERY DAY OF DECEMBER (ALL CODE UNTIL HERE)

# %% [markdown]
# Input variables: 54

# %% [raw]
# route,tripNum,shapeId,routeFrequency,shapeSequence,shapeLat,shapeLon,distanceTraveledShape,busCode,gpsPointId,gpsLat,gpsLon,distanceToShapePoint,gps_datetime,stopPointId,problem,alertDateTime,alertSubtype,alertType,alertRoadType,alertConfidence,alertNComments,alertNImages,alertNThumbsUp,alertReliability,alertReportMood,alertReportRating,alertSpeed,alertLatitude,alertLongitude,alertDistanceToClosestShapePoint,alertIsJamUnifiedAlert,alertInScale,jamUpdateDateTime,jamExpirationDateTime,jamBlockType,jamDelay,jamLength,jamLevel,jamSeverity,jamSpeedKM,jamDistanceToClosestShapePoint,headway,busBunching,nextBusCode,DAY(jamUpdateDateTime),YEAR(gps_datetime),YEAR(alertDateTime),YEAR(jamUpdateDateTime),MONTH(gps_datetime),MONTH(alertDateTime),MONTH(jamUpdateDateTime),WEEKDAY(gps_datetime),WEEKDAY(alertDateTime),WEEKDAY(jamUpdateDateTime)

# %%
# Importing required packages

import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
# Choose the city of analysis

city = 'Recife'
# city = 'CG'
# city = 'Curitiba'

# %%
# Put the integrated data path

file_name = "new_feats_data.csv"
new_feats_data_path = os.getcwd() + "/../data/output/" + city + "/" + file_name

# %%
# Importing the data after Feature Engineering

df = pd.read_csv(new_feats_data_path, index_col=None, header=0)

df.head()
# Out:
#    route  tripNum    shapeId routeFrequency  shapeSequence  shapeLat  \
# 0     96        1  Route_219  low_frequency          22857 -8.046589
# 1     96        1  Route_219  low_frequency          22857 -8.046589
# 2     96        1  Route_219  low_frequency          22857 -8.046589
# 3     96        2  Route_219  low_frequency          22857 -8.046589
# 4     96        2  Route_219  low_frequency          22857 -8.046589
#
#     shapeLon  distanceTraveledShape  busCode gpsPointId  ...  \
# 0 -34.878125                 3606.0    50665          -  ...
# 1 -34.878125                 3606.0    50673          -  ...
# 2 -34.878125                 3606.0    50662          -  ...
# 3 -34.878125                 3606.0    50673          -  ...
# 4 -34.878125                 3606.0    50662     176265  ...
#
#   DAY(jamUpdateDateTime) YEAR(gps_datetime) YEAR(alertDateTime)  \
# 0                      1               2018                2018
# ...

# %%
df.dtypes
# Out:
# route                                 int64
# tripNum                               int64
# shapeId                              object
# routeFrequency                       object
# shapeSequence                         int64
# shapeLat                            float64
# shapeLon                            float64
# distanceTraveledShape               float64
# busCode                               int64
# gpsPointId                           object
# gpsLat                               object
# gpsLon                               object
# distanceToShapePoint                 object
# stopPointId                           int64
# problem                              object
# alertSubtype                         object
# alertType                            object
# alertRoadType                        object
# alertConfidence                      object
# alertNComments                       object
# alertNImages                         object
# ...

# %% [markdown]
# ## 1. Checking Correlation
#
# ### 1.1. Pearson
#
# The Pearson correlation coefficient is a widely used approach that measures the linear dependence between two variables. The correlation coefficient ranges from -1 to 1.
# * 1: total positive correlation
# * -1: total negative correlation
# * 0: no correlation or non-linear correlation

# %%
pearson_corr = df.corr()
pearson_corr
# Out:
#                                route   tripNum  shapeSequence  shapeLat  \
# route                       1.000000  0.079596       0.781978  0.266511
# tripNum                     0.079596  1.000000       0.086730  0.115030
# shapeSequence               0.781978  0.086730       1.000000  0.308734
# shapeLat                    0.266511  0.115030       0.308734  1.000000
# shapeLon                    0.323485 -0.028413       0.239768  0.274632
# distanceTraveledShape      -0.048571 -0.123293      -0.012056 -0.065845
# busCode                     0.421343  0.079820       0.330627  0.523442
# stopPointId                 0.121191 -0.018236       0.046803  0.117877
# headway                     0.155121 -0.079597       0.138530  0.114442
# busBunching                -0.064539 -0.017179      -0.065098 -0.056183
# nextBusCode                 0.421332  0.080132       0.330462  0.523415
# DAY(gps_datetime)          -0.012667  0.096628      -0.007477 -0.068413
# ...

# %%
def plot_corr(df_corr):
    sns.heatmap(df_corr, 
            xticklabels=df_corr.columns.values,
            yticklabels=df_corr.columns.values, cmap="PiYG" )

# %%
plot_corr(pearson_corr)

# %% [markdown]
# ## Spearman

# %%
df.corr(method="spearman")
# Out:
#                                route   tripNum  shapeSequence  shapeLat  \
# route                       1.000000  0.041575       0.790968  0.252648
# tripNum                     0.041575  1.000000       0.051241  0.083568
# shapeSequence               0.790968  0.051241       1.000000  0.294458
# shapeLat                    0.252648  0.083568       0.294458  1.000000
# shapeLon                    0.562019 -0.023176       0.388404  0.238553
# distanceTraveledShape       0.027837 -0.085329       0.047528 -0.081642
# busCode                     0.666358  0.076454       0.511577  0.460403
# stopPointId                 0.286527 -0.021940       0.128056  0.006514
# headway                     0.223426 -0.004625       0.205571  0.150830
# busBunching                -0.080977 -0.014006      -0.077137 -0.045281
# nextBusCode                 0.666121  0.083968       0.503415  0.460079
# DAY(gps_datetime)          -0.039566  0.092678      -0.017271 -0.053361
# ...

# %% [markdown]
# ## Kendall

# %%
df.corr(method="kendall")
# Out:
#                                route   tripNum  shapeSequence  shapeLat  \
# route                       1.000000  0.029484       0.742864  0.149198
# tripNum                     0.029484  1.000000       0.035823  0.058433
# shapeSequence               0.742864  0.035823       1.000000  0.187733
# shapeLat                    0.149198  0.058433       0.187733  1.000000
# shapeLon                    0.419655 -0.016185       0.303308  0.110913
# distanceTraveledShape       0.020189 -0.060008       0.037992 -0.053855
# busCode                     0.503832  0.053643       0.405267  0.307317
# stopPointId                 0.226568 -0.014837       0.110862  0.041847
# headway                     0.151255 -0.002698       0.138236  0.100495
# busBunching                -0.066858 -0.011989      -0.062992 -0.036977
# nextBusCode                 0.504218  0.058569       0.403524  0.307265
# DAY(gps_datetime)          -0.032667  0.079328      -0.014103 -0.043575
# ...

# %% [markdown]
# Why 23 variables?
