# %%
import numpy as np
import pandas as pd
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, train_test_split
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
file_path = '../../data/input/integrated_data_dummy.csv'

input_data = pd.read_csv(file_path)

# %%
data = input_data[:50000]
data.shape
# Out:
# (50000, 456)

# %%
del input_data

# %%
data.isnull().any()
# Out:
# route                                                False
# tripNum                                              False
# shapeSequence                                        False
# shapeLat                                             False
# shapeLon                                             False
# distanceTraveledShape                                False
# busCode                                              False
# gpsPointId                                           False
# gpsLat                                               False
# gpsLon                                               False
# distanceToShapePoint                                 False
# stopPointId                                          False
# precipitation                                        False
# alertRoadType                                        False
# alertConfidence                                      False
# alertNComments                                       False
# alertNImages                                         False
# alertNThumbsUp                                       False
# alertReliability                                     False
# alertReportMood                                      False
# alertReportRating                                    False
# alertSpeed                                           False
# alertLatitude                                        False
# alertLongitude                                       False
# alertDistanceToClosestShapePoint                     False
# alertIsJamUnifiedAlert                               False
# alertInScale                                         False
# jamDelay                                             False
# jamLength                                            False
# jamLevel                                             False
#                                                      ...
# problemSB_TRIP_PROBLEM                               False
# alertSubtypeSB_-                                     False
# alertSubtypeSB_ACCIDENT_MAJOR                        False
# alertSubtypeSB_ACCIDENT_MINOR                        False
# alertSubtypeSB_HAZARD_ON_ROAD                        False
# alertSubtypeSB_HAZARD_ON_ROAD_CAR_STOPPED            False
# alertSubtypeSB_HAZARD_ON_ROAD_CONSTRUCTION           False
# alertSubtypeSB_HAZARD_ON_ROAD_OBJECT                 False
# alertSubtypeSB_HAZARD_ON_ROAD_POT_HOLE               False
# alertSubtypeSB_HAZARD_ON_ROAD_TRAFFIC_LIGHT_FAULT    False
# alertSubtypeSB_HAZARD_ON_SHOULDER_ANIMALS            False
# alertSubtypeSB_HAZARD_ON_SHOULDER_CAR_STOPPED        False
# alertSubtypeSB_HAZARD_ON_SHOULDER_MISSING_SIGN       False
# alertSubtypeSB_HAZARD_WEATHER_FLOOD                  False
# alertSubtypeSB_JAM_HEAVY_TRAFFIC                     False
# alertSubtypeSB_JAM_MODERATE_TRAFFIC                  False
# alertSubtypeSB_JAM_STAND_STILL_TRAFFIC               False
# alertSubtypeSB_POLICE_HIDING                         False
# alertSubtypeSB_POLICE_VISIBLE                        False
# alertSubtypeSB_ROAD_CLOSED_EVENT                     False
# alertTypeSB_-                                        False
# alertTypeSB_ACCIDENT                                 False
# alertTypeSB_CHIT_CHAT                                False
# alertTypeSB_HAZARD                                   False
# alertTypeSB_JAM                                      False
# alertTypeSB_POLICE                                   False
# alertTypeSB_ROAD_CLOSED                              False
# jamBlockTypeSB_-                                     False
# jamBlockTypeSB_ROAD_CLOSED_CONSTRUCTION              False
# jamBlockTypeSB_ROAD_CLOSED_EVENT                     False
# Length: 456, dtype: bool

# %%
target_col = ['headway']
bb_col = ['busBunching']
features = list(set(list(data.columns))-set(target_col)-set(bb_col))

# %%
# Normalize data
sc = StandardScaler()
data = sc.fit_transform(data)

# %%
# Balancing data

# %%
# Get label column and remove it from data
y = data['headway']
data.drop('headway', axis=1, inplace=True)
data.drop('busBunching', axis=1, inplace=True)

# %%
# Making training and test data: 80% Training, 20% Test
random.seed(15) #to get always the same set
train_X, test_X, train_Y, test_Y = train_test_split(data, y, test_size=0.20, random_state=7)

# %%
def rmse_cv(model, X_train, y_train):
    rmse = np.sqrt(-cross_val_score(model, X_train, y_train, scoring = "neg_mean_squared_error", cv = 5))
    return(rmse)

# function to plot the RMSE vs parameter value
def plot_rmse_param(series, param_name):
    series.plot(title = "Validation Error vs " + param_name)
    plt.xlabel(param_name)
    plt.ylabel("RMSE")
    
# function to get the best RMSE and the best parameter value of the model
def best_rmse_param(series):
    best_rmse = series.min()
    best_param = series.idxmin() 
    
    return(best_rmse, best_param)

# %% [markdown]
# ### Random Forest

# %%
n_estimators = [10, 50, 100]
cv_rf_rmse = [rmse_cv(RandomForestRegressor(n_estimators = n, n_jobs=8), train_X, train_Y).mean() 
            for n in n_estimators]

series = pd.Series(cv_rf_rmse, index = n_estimators)
plot_rmse_param(series, "n_estimators")
best_rmse_rf, best_estimator_rf = best_rmse_param(series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-056c3f327381> in <module>
#       5 series = pd.Series(cv_rf_rmse, index = n_estimators)
#       6 plot_rmse_param(series, "n_estimators")
# ----> 7 best_rmse_rf, best_estimator_rf = best_rmse_param(series)
#
# NameError: name 'best_rmse_param' is not defined

# %%
n_min_samples_split = [5, 10, 15, 20, 25]
cv_rf_rmse = [rmse_cv(RandomForestRegressor(n_estimators = best_estimator_rf, min_samples_split = n, n_jobs=8), 
                      train_X, train_Y).mean() 
            for n in n_min_samples_split]

series = pd.Series(cv_rf_rmse, index = n_min_samples_split)
plot_rmse_param(series, "n_min_samples_split")
best_rmse_rf, best_split_rf = best_rmse_param(series)

# %%
random.seed(42)
rf = RandomForestRegressor(n_estimators=best_estimator_rf, min_samples_split=best_split_rf, n_jobs=8)
rf.fit(train_X, train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=8,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)

# %%
pred = rf.predict(test_X)
rmse_rf = np.sqrt(mean_squared_error(test_Y,pred))
print(rmse_rf)
# Out:
# 15.131808441326017

# %%
#create dictionary
f_imps = {}
for i in range(num_features):
    f_imps[features[i]] = rf.feature_importances_[i]
    
#sort dictionary 
sorted_feature_names = sorted(f_imps, key=f_imps.__getitem__, reverse=True)
sorted_values = sorted(f_imps.values(), reverse=True)

num_to_print = 20
for i in range(num_to_print):
    print("%15s %4.3f" % (sorted_feature_names[i], sorted_values[i]))

# %% [markdown]
# ### ANN

# %%
# Define model
model = Sequential()
model.add(Dense(200, input_dim=len(features), activation= "relu"))
model.add(Dense(100, activation= "relu"))
model.add(Dense(50, activation= "relu"))
model.add(Dense(1))
#print(model.summary()) #Print model Summary

# Compile model
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0809 12:58:13.349483 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0809 12:58:18.313309 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0809 12:58:19.396915 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0809 12:58:21.060041 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Fit Model
model_history = model.fit(train_X, train_Y, epochs=100, batch_size=64)
# Out:
# W0809 12:58:23.233191 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0809 12:58:23.361865 139974974109504 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/100
# 40000/40000 [==============================] - 5s 134us/step - loss: 24706.5329 - mean_squared_error: 24706.5329
# Epoch 2/100
# 40000/40000 [==============================] - 2s 39us/step - loss: 6781.4499 - mean_squared_error: 6781.4499
# Epoch 3/100
# 40000/40000 [==============================] - 2s 39us/step - loss: 5600.8437 - mean_squared_error: 5600.8437
# Epoch 4/100
# 40000/40000 [==============================] - 2s 39us/step - loss: 4510.8640 - mean_squared_error: 4510.8640
# Epoch 5/100
# 40000/40000 [==============================] - 2s 39us/step - loss:
100
# 40000/40000 [==============================] - 2s 39us/step - loss: 2585.6718 - mean_squared_error: 2585.6718
# Epoch 99/100
# 40000/40000 [==============================] - 2s 39us/step - loss: 2607.9753 - mean_squared_error: 2607.9753
# Epoch 100/100
# 40000/40000 [==============================] - 2s 40us/step - loss: 2603.5063 - mean_squared_error: 2603.5063

# %%
def train_model(activation, loss, optimizer, batch_size):
    # Define model
    model = Sequential()
    model.add(Dense(200, input_dim=len(features), activation=activation))
    model.add(Dense(100, activation=activation))
    model.add(Dense(50, activation=activation))
    model.add(Dense(1))
    #print(model.summary()) #Print model Summary

    # Compile model
    model.compile(loss=loss, optimizer=optimizer, metrics=["mean_squared_error"])
    model.fit(train_X, train_Y, epochs=100, batch_size=batch_size)
    return model

# %%
parameters = {'activation': ['relu', 'elu', 'tanh'],
              'optimizer': ['adam', 'nadam', 'sgd'],
              'loss': ['mse', 'mape'],
              'batch_size': [16, 32, 64, 128]}

model = KerasRegressor(build_fn=train_model)
gridSearch = GridSearchCV(estimator=model,
                          param_grid=parameters,
                          cv=10,
                          n_jobs=8,
                          return_train_score=True).fit(train_X, train_Y)
# Out:
# W0812 05:57:38.908130 139891757557568 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0812 05:57:39.838128 139891757557568 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0812 05:57:40.684146 139891757557568 deprecation_wrapper.py:119] From /home/veruska/.local/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-470ccb8048f2> in <module>
#       8 }
#       9
# ---> 10 talos.Scan(train_X, train_Y, model=train_model(parameters), params=parameters)
#
# <ipython-input-14-7f7c780bade8> in train_model(param)
#       9
#      10     # Compile model
# ---> 11     model.compile(loss=param['losses'], optimizer=param['optimizer'], metrics=["mean_squared_error"])
#      12     model.fit(train_X, train_Y, epochs=100, batch_size=param['batch_size'])
#      13     return model
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#      94                 `optimizer`, `loss`, `metrics` or `sample_weight_mode`.
#      95         """
# ---> 96         self.optimizer = optimizers.get(optimizer)
#      97         self.loss = loss or []
#      98         self.metrics = metrics or []
#
# ~/.local/lib/python3.6/site-packages/keras/optimizers.py in get(identifier)
#     799     else:
#     800         raise ValueError('Could not interpret optimizer identifier: ' +
# --> 801                          str(identifier))
#
# ValueError: Could not interpret optimizer identifier: ['adam', 'nadam', 'sgd']

# %%
print('Grid Search Best score', gridSearch.best_score_)
print('Grid Search Best Parameters', gridSearch.best_params_)
print('Execution time', gridSearch.refit_time_)

# %%
pred = model.predict(test_X)
rmse_ann = np.sqrt(mean_squared_error(test_Y, pred))
print(rmse_ann)
# Out:
# 42.31377983518638

# %%
model_history.history
# Out:
# {'loss': [44690.78433881836,
#   9082.427299414063,
#   5977.148017700195,
#   4328.264370678711,
#   3566.3321436035158,
#   3311.1049875976564,
#   3273.8128224243164,
#   3240.311217565918,
#   3232.6591270629883,
#   3177.973301098633,
#   3154.6804920776367,
#   3125.0102064331054,
#   3113.6370058898924,
#   3113.436449005127,
#   3102.697121899414,
#   3093.4500321655273,
#   3105.932804602051,
#   3076.584989868164,
#   3066.832883959961,
#   3058.2531431396483,
#   3067.1507426635744,
#   3048.4223239440917,
#   3035.6709106689455,
#   3038.132729577637,
#   3020.1827871398928,
#   3026.3447428833006,
#   3022.3907741455077,
#   3004.562352050781,
#   2998.114367578125,
#   3046.4862752563477,
#   3039.7837607666015,
#   3012.919372961426,
#   2983.1940209655763,
#   2984.8394031066896,
#   2972.1017413208006,
#   2968.7090677124024,
#   2964.3215465820313,
#   2975.142423815918,
#   2951.0407376525877,
#   2954.825774560547,
#   2950.014495812988,
#   2961.0564039367678,
#   2936.524281958008,
#   2940.426338806152,
#   2481.9354856323243,
#   2481.61922210083,
#   2467.470025524902,
#   2482.377519958496,
#   2472.417574267578,
#   2481.8030033569335,
#   2471.975099725342,
#   2484.278614477539,
#   2461.4734839294433,
#   2469.8224833862305,
#   2515.5785735961913,
#   2485.8044861206054,
#   2462.4664172851562,
#   2480.6423028808595,
#   2484.168857104492,
#   2495.305008081055,
#   2488.1520979675292,
#   2487.0559226928713,
#   2492.1870960876463,
#   2488.8840041015624,
#   2466.136432385254,
#   2483.6602893798827,
#   2456.894630340576,
#   2484.0136229248046,
#   2485.705875164795,
#   2475.3012381347658,
#   2479.1807380859377,
#   2463.9779762634275,
#   2477.3875711975097,
#   2479.8009657836915,
#   2471.0598669189453,
#   2468.0140257446287,
#   2484.4316021362306,
#   2470.801696411133,
#   2459.95755045166,
#   2453.6265499389647,
#   2474.9720044067385,
#   2474.521582556152,
#   2478.545668225098,
#   2477.0811818237303,
#   2480.690676123047,
#   2478.2156184692385,
#   2465.8450304626463,
#   2478.707103399658,
#   2468.089318273926,
#   2492.1769272338865,
#   2470.3018681640624,
#   2484.107666015625,
#   2479.6001109313966,
#   2497.2038558532713,
#   2486.3163144836426,
#   2475.7540056640623,
#   2503.4641254882813,
#   2500.293257849121,
#   2516.0172668823243,
#   2513.2251219177247,
#   2463.659696350098,
#   2469.133997393799]}

# %%
# Plot training & validation accuracy values
plt.plot(model_history.history['mean_squared_error'])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model_history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### LSTM

# %%
# Define model
model = Sequential()
model.add(Dense(100, input_dim=len(features), activation= "relu"))
model.add(LSTM(units=100))
model.add(LSTM(units=50))
model.add(Dense(1))
print(model.summary()) #Print model Summary

# Compile model
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f56e30e2732a> in <module>
#       2 model = Sequential()
#       3 model.add(Dense(100, input_dim=len(features), activation= "relu"))
# ----> 4 model.add(LSTM(units=100))
#       5 model.add(LSTM(units=50))
#       6 model.add(Dense(1))
#
# ~/.local/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     179                 self.inputs = network.get_source_inputs(self.outputs[0])
#     180         elif self.outputs:
# --> 181             output_tensor = layer(self.outputs[0])
#     182             if isinstance(output_tensor, list):
#     183                 raise TypeError('All layers in a Sequential model '
#
# ~/.local/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     530
#     531         if initial_state is None and constants is None:
# --> 532             return super(RNN, self).__call__(inputs, **kwargs)
#     533
#     534         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/.local/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     412                 # Raise exceptions in case the input is not compatible
#     413                 # with the input_spec specified in the layer constructor.
# --> 414                 self.assert_input_compatibility(inputs)
#     415
#     416                 # Collect input shapes to build layer.
#
# ~/.local/lib/python3.6/site-packages/keras/engine/base_layer.py in assert_input_compatibility(self, inputs)
#     309                                      self.name + ': expected ndim=' +
#     310                                      str(spec.ndim) + ', found ndim=' +
# --> 311                                      str(K.ndim(x)))
#     312             if spec.max_ndim is not None:
#     313                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer lstm_1: expected ndim=3, found ndim=2

# %%
# Fit Model
model_history = model.fit(train_X, train_Y, epochs=10)
